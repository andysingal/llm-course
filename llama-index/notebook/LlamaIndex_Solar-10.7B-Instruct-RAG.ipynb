# %% [markdown]
# ### Solar 10.7B Instruct
#
# This notebook demonstrates the use of LlamaIndex for Retrieval Augmented Generation in Linux and with Nvidia's CUDA.
#
# See the [README.md](README.md) file for help on how to run this.

# %% [markdown]
# #### 1. Prepare Llama Index for use

# %%
import logging
import sys

logging.basicConfig(stream=sys.stdout, level=logging.INFO)
logging.getLogger().addHandler(logging.StreamHandler(stream=sys.stdout))

from llama_index import VectorStoreIndex
from llama_index import SimpleDirectoryReader
from llama_index import ServiceContext
# Out:
# INFO:numexpr.utils:Note: NumExpr detected 24 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# Note: NumExpr detected 24 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# NumExpr defaulting to 8 threads.

# %% [markdown]
# #### 2. Load the Word document(s)
#
# Note: A fictitious story about Thundertooth a dinosaur who has travelled to the future. Thanks ChatGPT!

# %%
documents = SimpleDirectoryReader("./Data/").load_data()

# %% [markdown]
# #### 3. Instantiate the model

# %%
import torch

from llama_index.llms import LlamaCPP
from llama_index.llms.llama_utils import messages_to_prompt, completion_to_prompt
llm = LlamaCPP(
    model_url=None, # We'll load locally.
    model_path='./Models/solar-10.7b-instruct-v1.0.Q5_K_M.gguf',
    temperature=0.1,
    max_new_tokens=1024, # Increasing to support longer responses
    context_window=4096, # Context Window
    generate_kwargs={},
    # set to at least 1 to use GPU
    model_kwargs={"n_gpu_layers": 49}, # 49 was all that was needed and that fit on the RTX 3090's 24GB
    messages_to_prompt=messages_to_prompt,
    completion_to_prompt=completion_to_prompt,
    verbose=True
)
# Out:
# ggml_init_cublas: GGML_CUDA_FORCE_MMQ:   no
# ggml_init_cublas: CUDA_USE_TENSOR_CORES: yes
# ggml_init_cublas: found 1 CUDA devices:
#   Device 0: NVIDIA GeForce RTX 3090, compute capability 8.6
# llama_model_loader: loaded meta data with 24 key-value pairs and 435 tensors from ./Models/solar-10.7b-instruct-v1.0.Q5_K_M.gguf (version GGUF V3 (latest))
# llama_model_loader: - tensor    0:                token_embd.weight q5_K     [  4096, 32000,     1,     1 ]
# llama_model_loader: - tensor    1:           blk.0.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor    2:            blk.0.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor    3:            blk.0.ffn_gate.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor    4:              blk.0.ffn_up.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor    5:            blk.0.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor    6:              blk.0.attn_k.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor    7:         blk.0.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor    8:              blk.0.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor    9:              blk.0.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor   10:           blk.1.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   11:            blk.1.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor   12:            blk.1.ffn_gate.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor   13:              blk.1.ffn_up.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor   14:            blk.1.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   15:              blk.1.attn_k.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor   16:         blk.1.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   17:              blk.1.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   18:              blk.1.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor   19:           blk.10.ffn_gate.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor   20:             blk.10.ffn_up.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor   21:             blk.10.attn_k.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor   22:        blk.10.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   23:             blk.10.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   24:             blk.10.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor   25:           blk.2.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   26:            blk.2.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor   27:            blk.2.ffn_gate.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor   28:              blk.2.ffn_up.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor   29:            blk.2.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   30:              blk.2.attn_k.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor   31:         blk.2.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   32:              blk.2.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   33:              blk.2.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor   34:           blk.3.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   35:            blk.3.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor   36:            blk.3.ffn_gate.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor   37:              blk.3.ffn_up.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor   38:            blk.3.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   39:              blk.3.attn_k.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor   40:         blk.3.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   41:              blk.3.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   42:              blk.3.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor   43:           blk.4.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   44:            blk.4.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor   45:            blk.4.ffn_gate.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor   46:              blk.4.ffn_up.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor   47:            blk.4.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   48:              blk.4.attn_k.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor   49:         blk.4.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   50:              blk.4.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   51:              blk.4.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor   52:           blk.5.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   53:            blk.5.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor   54:            blk.5.ffn_gate.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor   55:              blk.5.ffn_up.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor   56:            blk.5.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   57:              blk.5.attn_k.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor   58:         blk.5.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   59:              blk.5.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   60:              blk.5.attn_v.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor   61:           blk.6.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   62:            blk.6.ffn_down.weight q5_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor   63:            blk.6.ffn_gate.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor   64:              blk.6.ffn_up.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor   65:            blk.6.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   66:              blk.6.attn_k.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor   67:         blk.6.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   68:              blk.6.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   69:              blk.6.attn_v.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor   70:           blk.7.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   71:            blk.7.ffn_down.weight q5_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor   72:            blk.7.ffn_gate.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor   73:              blk.7.ffn_up.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor   74:            blk.7.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   75:              blk.7.attn_k.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor   76:         blk.7.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   77:              blk.7.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   78:              blk.7.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor   79:           blk.8.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   80:            blk.8.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor   81:            blk.8.ffn_gate.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor   82:              blk.8.ffn_up.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor   83:            blk.8.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   84:              blk.8.attn_k.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor   85:         blk.8.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   86:              blk.8.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   87:              blk.8.attn_v.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor   88:           blk.9.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   89:            blk.9.ffn_down.weight q5_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor   90:            blk.9.ffn_gate.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor   91:              blk.9.ffn_up.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor   92:            blk.9.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   93:              blk.9.attn_k.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor   94:         blk.9.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   95:              blk.9.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   96:              blk.9.attn_v.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor   97:          blk.10.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   98:           blk.10.ffn_down.weight q5_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor   99:           blk.10.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  100:          blk.11.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  101:           blk.11.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  102:           blk.11.ffn_gate.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  103:             blk.11.ffn_up.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  104:           blk.11.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  105:             blk.11.attn_k.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  106:        blk.11.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  107:             blk.11.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  108:             blk.11.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  109:          blk.12.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  110:           blk.12.ffn_down.weight q5_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  111:           blk.12.ffn_gate.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  112:             blk.12.ffn_up.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  113:           blk.12.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  114:             blk.12.attn_k.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  115:        blk.12.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  116:             blk.12.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  117:             blk.12.attn_v.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  118:          blk.13.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  119:           blk.13.ffn_down.weight q5_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  120:           blk.13.ffn_gate.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  121:             blk.13.ffn_up.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  122:           blk.13.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  123:             blk.13.attn_k.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  124:        blk.13.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  125:             blk.13.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  126:             blk.13.attn_v.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  127:          blk.14.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  128:           blk.14.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  129:           blk.14.ffn_gate.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  130:             blk.14.ffn_up.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  131:           blk.14.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  132:             blk.14.attn_k.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  133:        blk.14.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  134:             blk.14.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  135:             blk.14.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  136:          blk.15.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  137:           blk.15.ffn_down.weight q5_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  138:           blk.15.ffn_gate.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  139:             blk.15.ffn_up.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  140:           blk.15.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  141:             blk.15.attn_k.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  142:        blk.15.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  143:             blk.15.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  144:             blk.15.attn_v.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  145:          blk.16.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  146:           blk.16.ffn_down.weight q5_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  147:           blk.16.ffn_gate.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  148:             blk.16.ffn_up.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  149:           blk.16.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  150:             blk.16.attn_k.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  151:        blk.16.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  152:             blk.16.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  153:             blk.16.attn_v.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  154:          blk.17.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  155:           blk.17.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  156:           blk.17.ffn_gate.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  157:             blk.17.ffn_up.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  158:           blk.17.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  159:             blk.17.attn_k.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  160:        blk.17.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  161:             blk.17.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  162:             blk.17.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  163:          blk.18.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  164:           blk.18.ffn_down.weight q5_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  165:           blk.18.ffn_gate.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  166:             blk.18.ffn_up.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  167:           blk.18.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  168:             blk.18.attn_k.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  169:        blk.18.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  170:             blk.18.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  171:             blk.18.attn_v.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  172:          blk.19.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  173:           blk.19.ffn_down.weight q5_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  174:           blk.19.ffn_gate.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  175:             blk.19.ffn_up.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  176:           blk.19.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  177:             blk.19.attn_k.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  178:        blk.19.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  179:             blk.19.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  180:             blk.19.attn_v.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  181:          blk.20.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  182:           blk.20.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  183:           blk.20.ffn_gate.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  184:             blk.20.ffn_up.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  185:           blk.20.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  186:             blk.20.attn_k.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  187:        blk.20.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  188:             blk.20.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  189:             blk.20.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  190:          blk.21.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  191:           blk.21.ffn_down.weight q5_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  192:           blk.21.ffn_gate.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  193:             blk.21.ffn_up.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  194:           blk.21.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  195:             blk.21.attn_k.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  196:        blk.21.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  197:             blk.21.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  198:             blk.21.attn_v.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  199:             blk.22.attn_k.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  200:        blk.22.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  201:             blk.22.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  202:             blk.22.attn_v.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  203:          blk.22.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  204:           blk.22.ffn_down.weight q5_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  205:           blk.22.ffn_gate.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  206:             blk.22.ffn_up.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  207:           blk.22.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  208:          blk.23.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  209:           blk.23.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  210:           blk.23.ffn_gate.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  211:             blk.23.ffn_up.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  212:           blk.23.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  213:             blk.23.attn_k.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  214:        blk.23.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  215:             blk.23.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  216:             blk.23.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  217:          blk.24.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  218:           blk.24.ffn_down.weight q5_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  219:           blk.24.ffn_gate.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  220:             blk.24.ffn_up.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  221:           blk.24.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  222:             blk.24.attn_k.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  223:        blk.24.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  224:             blk.24.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  225:             blk.24.attn_v.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  226:          blk.25.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  227:           blk.25.ffn_down.weight q5_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  228:           blk.25.ffn_gate.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  229:             blk.25.ffn_up.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  230:           blk.25.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  231:             blk.25.attn_k.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  232:        blk.25.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  233:             blk.25.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  234:             blk.25.attn_v.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  235:          blk.26.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  236:           blk.26.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  237:           blk.26.ffn_gate.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  238:             blk.26.ffn_up.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  239:           blk.26.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  240:             blk.26.attn_k.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  241:        blk.26.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  242:             blk.26.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  243:             blk.26.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  244:          blk.27.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  245:           blk.27.ffn_down.weight q5_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  246:           blk.27.ffn_gate.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  247:             blk.27.ffn_up.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  248:           blk.27.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  249:             blk.27.attn_k.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  250:        blk.27.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  251:             blk.27.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  252:             blk.27.attn_v.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  253:          blk.28.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  254:           blk.28.ffn_down.weight q5_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  255:           blk.28.ffn_gate.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  256:             blk.28.ffn_up.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  257:           blk.28.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  258:             blk.28.attn_k.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  259:        blk.28.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  260:             blk.28.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  261:             blk.28.attn_v.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  262:          blk.29.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  263:           blk.29.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  264:           blk.29.ffn_gate.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  265:             blk.29.ffn_up.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  266:           blk.29.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  267:             blk.29.attn_k.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  268:        blk.29.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  269:             blk.29.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  270:             blk.29.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  271:          blk.30.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  272:           blk.30.ffn_down.weight q5_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  273:           blk.30.ffn_gate.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  274:             blk.30.ffn_up.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  275:           blk.30.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  276:             blk.30.attn_k.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  277:        blk.30.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  278:             blk.30.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  279:             blk.30.attn_v.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  280:          blk.31.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  281:           blk.31.ffn_down.weight q5_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  282:           blk.31.ffn_gate.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  283:             blk.31.ffn_up.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  284:           blk.31.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  285:             blk.31.attn_k.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  286:        blk.31.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  287:             blk.31.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  288:             blk.31.attn_v.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  289:          blk.32.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  290:           blk.32.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  291:           blk.32.ffn_gate.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  292:             blk.32.ffn_up.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  293:           blk.32.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  294:             blk.32.attn_k.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  295:        blk.32.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  296:             blk.32.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  297:             blk.32.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  298:           blk.33.ffn_gate.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  299:             blk.33.attn_k.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  300:        blk.33.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  301:             blk.33.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  302:             blk.33.attn_v.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  303:          blk.33.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  304:           blk.33.ffn_down.weight q5_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  305:             blk.33.ffn_up.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  306:           blk.33.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  307:          blk.34.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  308:           blk.34.ffn_down.weight q5_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  309:           blk.34.ffn_gate.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  310:             blk.34.ffn_up.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  311:           blk.34.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  312:             blk.34.attn_k.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  313:        blk.34.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  314:             blk.34.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  315:             blk.34.attn_v.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  316:          blk.35.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  317:           blk.35.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  318:           blk.35.ffn_gate.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  319:             blk.35.ffn_up.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  320:           blk.35.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  321:             blk.35.attn_k.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  322:        blk.35.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  323:             blk.35.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  324:             blk.35.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  325:          blk.36.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  326:           blk.36.ffn_down.weight q5_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  327:           blk.36.ffn_gate.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  328:             blk.36.ffn_up.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  329:           blk.36.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  330:             blk.36.attn_k.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  331:        blk.36.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  332:             blk.36.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  333:             blk.36.attn_v.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  334:          blk.37.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  335:           blk.37.ffn_down.weight q5_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  336:           blk.37.ffn_gate.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  337:             blk.37.ffn_up.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  338:           blk.37.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  339:             blk.37.attn_k.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  340:        blk.37.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  341:             blk.37.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  342:             blk.37.attn_v.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  343:          blk.38.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  344:           blk.38.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  345:           blk.38.ffn_gate.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  346:             blk.38.ffn_up.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  347:           blk.38.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  348:             blk.38.attn_k.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  349:        blk.38.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  350:             blk.38.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  351:             blk.38.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  352:          blk.39.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  353:           blk.39.ffn_down.weight q5_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  354:           blk.39.ffn_gate.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  355:             blk.39.ffn_up.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  356:           blk.39.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  357:             blk.39.attn_k.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  358:        blk.39.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  359:             blk.39.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  360:             blk.39.attn_v.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  361:          blk.40.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  362:           blk.40.ffn_down.weight q5_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  363:           blk.40.ffn_gate.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  364:             blk.40.ffn_up.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  365:           blk.40.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  366:             blk.40.attn_k.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  367:        blk.40.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  368:             blk.40.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  369:             blk.40.attn_v.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  370:          blk.41.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  371:           blk.41.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  372:           blk.41.ffn_gate.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  373:             blk.41.ffn_up.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  374:           blk.41.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  375:             blk.41.attn_k.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  376:        blk.41.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  377:             blk.41.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  378:             blk.41.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  379:          blk.42.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  380:           blk.42.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  381:           blk.42.ffn_gate.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  382:             blk.42.ffn_up.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  383:           blk.42.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  384:             blk.42.attn_k.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  385:        blk.42.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  386:             blk.42.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  387:             blk.42.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  388:          blk.43.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  389:           blk.43.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  390:           blk.43.ffn_gate.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  391:             blk.43.ffn_up.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  392:           blk.43.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  393:             blk.43.attn_k.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  394:        blk.43.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  395:             blk.43.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  396:             blk.43.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  397:           blk.44.ffn_gate.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  398:             blk.44.ffn_up.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  399:             blk.44.attn_k.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  400:        blk.44.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  401:             blk.44.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  402:             blk.44.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  403:                    output.weight q6_K     [  4096, 32000,     1,     1 ]
# llama_model_loader: - tensor  404:          blk.44.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  405:           blk.44.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  406:           blk.44.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  407:          blk.45.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  408:           blk.45.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  409:           blk.45.ffn_gate.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  410:             blk.45.ffn_up.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  411:           blk.45.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  412:             blk.45.attn_k.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  413:        blk.45.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  414:             blk.45.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  415:             blk.45.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  416:          blk.46.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  417:           blk.46.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  418:           blk.46.ffn_gate.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  419:             blk.46.ffn_up.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  420:           blk.46.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  421:             blk.46.attn_k.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  422:        blk.46.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  423:             blk.46.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  424:             blk.46.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  425:          blk.47.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  426:           blk.47.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# llama_model_loader: - tensor  427:           blk.47.ffn_gate.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  428:             blk.47.ffn_up.weight q5_K     [  4096, 14336,     1,     1 ]
# llama_model_loader: - tensor  429:           blk.47.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  430:             blk.47.attn_k.weight q5_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  431:        blk.47.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  432:             blk.47.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  433:             blk.47.attn_v.weight q6_K     [  4096,  1024,     1,     1 ]
# llama_model_loader: - tensor  434:               output_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = LLaMA v2
# llama_model_loader: - kv   2:                       llama.context_length u32              = 4096
# llama_model_loader: - kv   3:                     llama.embedding_length u32              = 4096
# llama_model_loader: - kv   4:                          llama.block_count u32              = 48
# llama_model_loader: - kv   5:                  llama.feed_forward_length u32              = 14336
# llama_model_loader: - kv   6:                 llama.rope.dimension_count u32              = 128
# llama_model_loader: - kv   7:                 llama.attention.head_count u32              = 32
# llama_model_loader: - kv   8:              llama.attention.head_count_kv u32              = 8
# llama_model_loader: - kv   9:     llama.attention.layer_norm_rms_epsilon f32              = 0.000010
# llama_model_loader: - kv  10:                       llama.rope.freq_base f32              = 10000.000000
# llama_model_loader: - kv  11:                          general.file_type u32              = 17
# llama_model_loader: - kv  12:                       tokenizer.ggml.model str              = llama
# llama_model_loader: - kv  13:                      tokenizer.ggml.tokens arr[str,32000]   = ["<unk>", "<s>", "</s>", "<0x00>", "<...
# llama_model_loader: - kv  14:                      tokenizer.ggml.scores arr[f32,32000]   = [0.000000, 0.000000, 0.000000, 0.0000...
# llama_model_loader: - kv  15:                  tokenizer.ggml.token_type arr[i32,32000]   = [2, 3, 3, 6, 6, 6, 6, 6, 6, 6, 6, 6, ...
# llama_model_loader: - kv  16:                tokenizer.ggml.bos_token_id u32              = 1
# llama_model_loader: - kv  17:                tokenizer.ggml.eos_token_id u32              = 2
# llama_model_loader: - kv  18:            tokenizer.ggml.unknown_token_id u32              = 0
# llama_model_loader: - kv  19:            tokenizer.ggml.padding_token_id u32              = 2
# llama_model_loader: - kv  20:               tokenizer.ggml.add_bos_token bool             = true
# llama_model_loader: - kv  21:               tokenizer.ggml.add_eos_token bool             = false
# llama_model_loader: - kv  22:                    tokenizer.chat_template str              = {% for message in messages %}{% if me...
# llama_model_loader: - kv  23:               general.quantization_version u32              = 2
# llama_model_loader: - type  f32:   97 tensors
# llama_model_loader: - type q5_K:  289 tensors
# llama_model_loader: - type q6_K:   49 tensors
# llm_load_vocab: special tokens definition check successful ( 259/32000 ).
# llm_load_print_meta: format           = GGUF V3 (latest)
# llm_load_print_meta: arch             = llama
# llm_load_print_meta: vocab type       = SPM
# llm_load_print_meta: n_vocab          = 32000
# llm_load_print_meta: n_merges         = 0
# llm_load_print_meta: n_ctx_train      = 4096
# llm_load_print_meta: n_embd           = 4096
# llm_load_print_meta: n_head           = 32
# llm_load_print_meta: n_head_kv        = 8
# llm_load_print_meta: n_layer          = 48
# llm_load_print_meta: n_rot            = 128
# llm_load_print_meta: n_gqa            = 4
# llm_load_print_meta: f_norm_eps       = 0.0e+00
# llm_load_print_meta: f_norm_rms_eps   = 1.0e-05
# llm_load_print_meta: f_clamp_kqv      = 0.0e+00
# llm_load_print_meta: f_max_alibi_bias = 0.0e+00
# llm_load_print_meta: n_ff             = 14336
# llm_load_print_meta: n_expert         = 0
# llm_load_print_meta: n_expert_used    = 0
# llm_load_print_meta: rope scaling     = linear
# llm_load_print_meta: freq_base_train  = 10000.0
# llm_load_print_meta: freq_scale_train = 1
# llm_load_print_meta: n_yarn_orig_ctx  = 4096
# llm_load_print_meta: rope_finetuned   = unknown
# llm_load_print_meta: model type       = 34B
# llm_load_print_meta: model ftype      = Q5_K - Medium
# llm_load_print_meta: model params     = 10.73 B
# llm_load_print_meta: model size       = 7.08 GiB (5.66 BPW)
# llm_load_print_meta: general.name     = LLaMA v2
# llm_load_print_meta: BOS token        = 1 '<s>'
# llm_load_print_meta: EOS token        = 2 '</s>'
# llm_load_print_meta: UNK token        = 0 '<unk>'
# llm_load_print_meta: PAD token        = 2 '</s>'
# llm_load_print_meta: LF token         = 13 '<0x0A>'
# llm_load_tensors: ggml ctx size =    0.17 MiB
# llm_load_tensors: using CUDA for GPU acceleration
# llm_load_tensors: mem required  =   86.10 MiB
# llm_load_tensors: offloading 48 repeating layers to GPU
# llm_load_tensors: offloading non-repeating layers to GPU
# llm_load_tensors: offloaded 49/49 layers to GPU
# llm_load_tensors: VRAM used: 7159.30 MiB
# ...................................................................................................
# llama_new_context_with_model: n_ctx      = 4096
# llama_new_context_with_model: freq_base  = 10000.0
# llama_new_context_with_model: freq_scale = 1
# llama_new_context_with_model: KV self size  =  768.00 MiB, K (f16):  384.00 MiB, V (f16):  384.00 MiB
# llama_build_graph: non-view tensors processed: 1012/1012
# llama_new_context_with_model: compute buffer total size = 291.19 MiB
# llama_new_context_with_model: VRAM scratch buffer: 288.00 MiB
# llama_new_context_with_model: total VRAM used: 7447.31 MiB (model: 7159.30 MiB, context: 288.00 MiB)
# AVX = 1 | AVX2 = 1 | AVX512 = 0 | AVX512_VBMI = 0 | AVX512_VNNI = 0 | FMA = 1 | NEON = 0 | ARM_FMA = 0 | F16C = 1 | FP16_VA = 0 | WASM_SIMD = 0 | BLAS = 1 | SSE3 = 1 | SSSE3 = 1 | VSX = 0 |

# %% [markdown]
# #### 4. Checkpoint
#
# Are you running on GPU? The above output should include near the top something like:
# > ggml_init_cublas: found 1 CUDA devices:
#
# And in the full text near the bottom should be:
# > llm_load_tensors: using CUDA for GPU acceleration

# %% [markdown]
# #### 5. Embeddings
#
# Convert your source document text into embeddings.
#
# The embedding model is from huggingface, this one performs well.
#
# > https://huggingface.co/thenlper/gte-large

# %%
from langchain.embeddings import HuggingFaceEmbeddings

embed_model = HuggingFaceEmbeddings(model_name="thenlper/gte-large", cache_folder=None)
# Out:
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: thenlper/gte-large
# Load pretrained SentenceTransformer: thenlper/gte-large
# INFO:sentence_transformers.SentenceTransformer:Did not find folder thenlper/gte-large
# Did not find folder thenlper/gte-large
# INFO:sentence_transformers.SentenceTransformer:Search model on server: http://sbert.net/models/thenlper/gte-large.zip
# Search model on server: http://sbert.net/models/thenlper/gte-large.zip
# INFO:sentence_transformers.SentenceTransformer:Load SentenceTransformer from folder: /home/mark/.cache/torch/sentence_transformers/sbert.net_models_thenlper_gte-large
# Load SentenceTransformer from folder: /home/mark/.cache/torch/sentence_transformers/sbert.net_models_thenlper_gte-large
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device: cuda
# Use pytorch device: cuda

# %% [markdown]
# #### 6. Prompt Template
#
# Prompt template for SOLAR 10.7B Instruct:
#
# &#35;&#35;&#35; User:<br>
# {prompt}<br>
#
# &#35;&#35;&#35; Assistant:

# %%
# Produces a prompt specific to the model
def modelspecific_prompt(promptmessage, questionText):
    return f"### User:\n{promptmessage}{questionText}\n\n###Assistant:"

# %% [markdown]
# #### 7. Service Context
#
# For chunking the document into tokens using the embedding model and our LLM

# %%
service_context = ServiceContext.from_defaults(
    chunk_size=256, # Number of tokens in each chunk
    llm=llm,
    embed_model=embed_model
)

# %% [markdown]
# #### 8. Index documents

# %%
index = VectorStoreIndex.from_documents(documents, service_context=service_context)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# #### 9. Query Engine
#
# Create a query engine, specifying how many citations we want to get back from the searched text (in this case 3).
#
# The DB_DOC_ID_KEY is used to get back the filename of the original document

# %%
from llama_index.query_engine import CitationQueryEngine
query_engine = CitationQueryEngine.from_args(
    index,
    similarity_top_k=3,
    # here we can control how granular citation sources are, the default is 512
    citation_chunk_size=256,
)

# For citations we get the document info
DB_DOC_ID_KEY = "db_document_id"

# %% [markdown]
# #### 10. Prompt and Response function
#
# Pass in a question, get a response back.
#
# IMPORTANT: The prompt is set here, adjust it to match what you want the LLM to act like and do.

# %%
def RunQuestion(questionText):
    systemmessage = "You are a story teller who likes to elaborate. Answer questions in a positive, helpful and interesting way. If the answer is not in the following context return ONLY 'Sorry, I don't know the answer to that'. Question: "

    queryQuestion = modelspecific_prompt(systemmessage, questionText)

    response = query_engine.query(queryQuestion)

    return response

# %% [markdown]
# #### 11. Questions to test with

# %%
TestQuestions = [
    "Summarise the story for me",
    "Who was the main protagonist?",
    "Did they have any children? If so, what were their names?",
    "Did anything eventful happen?",
]

# %% [markdown]
# #### 12. Run Questions through model (this can take a while) and see citations
#
# Runs each test question, saves it to a dictionary for output in the last step.
#
# Note: Citations are the source documents used and the text the response is based on. This is important for RAG so you can reference these documents for the user, and to ensure it's utilising the right documents.

# %%
qa_pairs = []

for index, question in enumerate(TestQuestions, start=1):
    question = question.strip() # Clean up

    print(f"\n{index}/{len(TestQuestions)}: {question}")

    response = RunQuestion(question) # Query and get  response

    qa_pairs.append((question.strip(), str(response).strip())) # Add to our output array

    # Displays the citations
    for index, node in enumerate(response.source_nodes, start=1):
        print(f"{index}/{len(response.source_nodes)}: |{node.node.metadata['file_name']}| {node.node.get_text()}")

    # Uncomment the following line if you want to test just the first question
    # break
# Out:
# 1/4: Summarise the story for me
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 1/4: |Thundertooth Part 1.docx| Source 1:
# "Hello there, majestic creature. What brings you to our time?" Mayor Grace inquired, her voice calm and reassuring.
#
#
#
# Thundertooth, though initially startled, found comfort in the mayor's soothing tone. In broken sentences, he explained his journey through time, the strange portal, and his hunger dilemma. Mayor Grace listened intently, her eyes widening with amazement at the tale of the prehistoric dinosaur navigating the future.
#
#
#
# Realizing the dinosaur's predicament, Mayor Grace extended an invitation. "You are welcome in our city, Thundertooth. We can find a way to provide for you without causing harm to anyone. Let us work together to find a solution."
#
#
#
# Grateful for the mayor's hospitality, Thundertooth followed her through the city. Together, they explored the futuristic marketplaces and innovative food labs, eventually discovering a sustainable solution that satisfied the dinosaur's hunger without compromising the well-being of the city's inhabitants.
#
# 2/4: |Thundertooth Part 1.docx| Source 2:
# "Hello there, majestic creature. What brings you to our time?" Mayor Grace inquired, her voice calm and reassuring.
#
#
#
# Thundertooth, though initially startled, found comfort in the mayor's soothing tone. In broken sentences, he explained his journey through time, the strange portal, and his hunger dilemma. Mayor Grace listened intently, her eyes widening with amazement at the tale of the prehistoric dinosaur navigating the future.
#
#
#
# Realizing the dinosaur's predicament, Mayor Grace extended an invitation. "You are welcome in our city, Thundertooth. We can find a way to provide for you without causing harm to anyone. Let us work together to find a solution."
#
#
#
# Grateful for the mayor's hospitality, Thundertooth followed her through the city. Together, they explored the futuristic marketplaces and innovative food labs, eventually discovering a sustainable solution that satisfied the dinosaur's hunger without compromising the well-being of the city's inhabitants.
#
# 3/4: |Thundertooth Part 1.docx| Source 3:
# As the news of Thundertooth's arrival spread, the city embraced the talking dinosaur as a symbol of unity between the past and the future. Thundertooth found a new home in the city's park, where holographic flowers bloomed, and the citizens marveled at the beauty of coexistence across time. And so, in this extraordinary city of flying cars and advanced technology, Thundertooth became a beloved figure, a living bridge between eras, teaching the people that understanding and cooperation could overcome even the greatest challenges.
#
# 4/4: |Thundertooth Part 3.docx| Source 4:
# The mayor, recognizing Thundertooth's intelligence and resourcefulness, approached him. "Thundertooth, we need a plan to divert or neutralize the meteor. Our technology can only do so much, but with your unique abilities, perhaps we can find a solution."
#
#
#
# Thundertooth nodded, understanding the gravity of the situation. He gathered Lumina, Echo, Sapphire, and Ignis, explaining the urgency and the role each of them would play in the impending crisis.
#
#
#
# 1. **Lumina**: Utilizing her deep understanding of technology, Lumina would enhance the city's energy systems to generate a powerful force field, providing a protective barrier against the meteor's impact.
#
#
#
# 2. **Echo**: With his extraordinary mimicry abilities, Echo would amplify the emergency signals, ensuring that every citizen received timely warnings and instructions for evacuation.
#
#
#
# 3. **Sapphire**: Harnessing her calming and healing powers, Sapphire would assist in calming the panicked masses, ensuring an orderly and efficient evacuation.
#
#
#
# 4. **Ignis**: Drawing upon his fiery talents, Ignis would create controlled bursts of heat, attempting to alter the meteor's trajectory and reduce its destructive force.
#
#
# 2/4: Who was the main protagonist?
# llama_print_timings:        load time =    2293.84 ms
# llama_print_timings:      sample time =     118.41 ms /   416 runs   (    0.28 ms per token,  3513.10 tokens per second)
# llama_print_timings: prompt eval time =    8169.06 ms /  1338 tokens (    6.11 ms per token,   163.79 tokens per second)
# llama_print_timings:        eval time =   40271.79 ms /   415 runs   (   97.04 ms per token,    10.30 tokens per second)
# llama_print_timings:       total time =   49422.15 ms
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Llama.generate: prefix-match hit
# 1/4: |Thundertooth Part 3.docx| Source 1:
# The mayor, recognizing Thundertooth's intelligence and resourcefulness, approached him. "Thundertooth, we need a plan to divert or neutralize the meteor. Our technology can only do so much, but with your unique abilities, perhaps we can find a solution."
#
#
#
# Thundertooth nodded, understanding the gravity of the situation. He gathered Lumina, Echo, Sapphire, and Ignis, explaining the urgency and the role each of them would play in the impending crisis.
#
#
#
# 1. **Lumina**: Utilizing her deep understanding of technology, Lumina would enhance the city's energy systems to generate a powerful force field, providing a protective barrier against the meteor's impact.
#
#
#
# 2. **Echo**: With his extraordinary mimicry abilities, Echo would amplify the emergency signals, ensuring that every citizen received timely warnings and instructions for evacuation.
#
#
#
# 3. **Sapphire**: Harnessing her calming and healing powers, Sapphire would assist in calming the panicked masses, ensuring an orderly and efficient evacuation.
#
#
#
# 4. **Ignis**: Drawing upon his fiery talents, Ignis would create controlled bursts of heat, attempting to alter the meteor's trajectory and reduce its destructive force.
#
# 2/4: |Thundertooth Part 3.docx| Source 2:
# Thundertooth, ever the protector of his newfound home, wasted no time. With a determined gleam in his eyes, he gathered his family and hurried to the city's command center, where Mayor Grace and the leading scientists were coordinating the evacuation efforts.
#
#
#
# The mayor, recognizing Thundertooth's intelligence and resourcefulness, approached him. "Thundertooth, we need a plan to divert or neutralize the meteor. Our technology can only do so much, but with your unique abilities, perhaps we can find a solution."
#
#
#
# Thundertooth nodded, understanding the gravity of the situation. He gathered Lumina, Echo, Sapphire, and Ignis, explaining the urgency and the role each of them would play in the impending crisis.
#
#
#
# 1. **Lumina**: Utilizing her deep understanding of technology, Lumina would enhance the city's energy systems to generate a powerful force field, providing a protective barrier against the meteor's impact.
#
#
#
# 2. **Echo**: With his extraordinary mimicry abilities, Echo would amplify the emergency signals, ensuring that every citizen received timely warnings and instructions for evacuation.
#
# 3/4: |Thundertooth Part 1.docx| Source 3:
# "Hello there, majestic creature. What brings you to our time?" Mayor Grace inquired, her voice calm and reassuring.
#
#
#
# Thundertooth, though initially startled, found comfort in the mayor's soothing tone. In broken sentences, he explained his journey through time, the strange portal, and his hunger dilemma. Mayor Grace listened intently, her eyes widening with amazement at the tale of the prehistoric dinosaur navigating the future.
#
#
#
# Realizing the dinosaur's predicament, Mayor Grace extended an invitation. "You are welcome in our city, Thundertooth. We can find a way to provide for you without causing harm to anyone. Let us work together to find a solution."
#
#
#
# Grateful for the mayor's hospitality, Thundertooth followed her through the city. Together, they explored the futuristic marketplaces and innovative food labs, eventually discovering a sustainable solution that satisfied the dinosaur's hunger without compromising the well-being of the city's inhabitants.
#
# 4/4: |Thundertooth Part 1.docx| Source 4:
# As the news of Thundertooth's arrival spread, the city embraced the talking dinosaur as a symbol of unity between the past and the future. Thundertooth found a new home in the city's park, where holographic flowers bloomed, and the citizens marveled at the beauty of coexistence across time. And so, in this extraordinary city of flying cars and advanced technology, Thundertooth became a beloved figure, a living bridge between eras, teaching the people that understanding and cooperation could overcome even the greatest challenges.
#
#
# 3/4: Did they have any children? If so, what were their names?
# llama_print_timings:        load time =    2293.84 ms
# llama_print_timings:      sample time =      23.42 ms /    84 runs   (    0.28 ms per token,  3586.68 tokens per second)
# llama_print_timings: prompt eval time =    7415.83 ms /  1082 tokens (    6.85 ms per token,   145.90 tokens per second)
# llama_print_timings:        eval time =    7512.67 ms /    83 runs   (   90.51 ms per token,    11.05 tokens per second)
# llama_print_timings:       total time =   15115.59 ms
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Llama.generate: prefix-match hit
# 1/5: |Thundertooth Part 2.docx| Source 1:
# As the years passed, Thundertooth's life took a heartwarming turn. He met a kind and intelligent dinosaur named Seraphina, and together they started a family. Thundertooth and Seraphina were blessed with four children, each with unique characteristics that mirrored the diversity of their modern world.
#
#
#
# Lumina: The eldest of Thundertooth's children, Lumina inherited her mother's intelligence and her father's sense of wonder. With sparkling scales that emitted a soft glow, Lumina had the ability to generate light at will. She became fascinated with technology, often spending hours tinkering with gadgets and inventing new ways to enhance the widgets produced in the family's factory.
#
#
#
# Echo: The second-born, Echo, had a gift for mimicry. He could perfectly replicate any sound or voice he heard, providing entertainment to the entire city. His playful nature and ability to bring joy to those around him made him a favorite among the neighborhood children.
#
# 2/5: |Thundertooth Part 2.docx| Source 2:
# As the years passed, Thundertooth's life took a heartwarming turn. He met a kind and intelligent dinosaur named Seraphina, and together they started a family. Thundertooth and Seraphina were blessed with four children, each with unique characteristics that mirrored the diversity of their modern world.
#
#
#
# Lumina: The eldest of Thundertooth's children, Lumina inherited her mother's intelligence and her father's sense of wonder. With sparkling scales that emitted a soft glow, Lumina had the ability to generate light at will. She became fascinated with technology, often spending hours tinkering with gadgets and inventing new ways to enhance the widgets produced in the family's factory.
#
#
#
# Echo: The second-born, Echo, had a gift for mimicry. He could perfectly replicate any sound or voice he heard, providing entertainment to the entire city. His playful nature and ability to bring joy to those around him made him a favorite among the neighborhood children.
#
# 3/5: |Thundertooth Part 2.docx| Source 3:
# Sapphire: Sapphire, the third sibling, had scales that shimmered like precious gems. She possessed a unique talent for calming and healing, a trait she inherited from both her parents. Whenever someone in the city felt stressed or unwell, Sapphire would extend her gentle touch, bringing comfort and tranquility.
#
# 4/5: |Thundertooth Part 1.docx| Source 4:
# "Hello there, majestic creature. What brings you to our time?" Mayor Grace inquired, her voice calm and reassuring.
#
#
#
# Thundertooth, though initially startled, found comfort in the mayor's soothing tone. In broken sentences, he explained his journey through time, the strange portal, and his hunger dilemma. Mayor Grace listened intently, her eyes widening with amazement at the tale of the prehistoric dinosaur navigating the future.
#
#
#
# Realizing the dinosaur's predicament, Mayor Grace extended an invitation. "You are welcome in our city, Thundertooth. We can find a way to provide for you without causing harm to anyone. Let us work together to find a solution."
#
#
#
# Grateful for the mayor's hospitality, Thundertooth followed her through the city. Together, they explored the futuristic marketplaces and innovative food labs, eventually discovering a sustainable solution that satisfied the dinosaur's hunger without compromising the well-being of the city's inhabitants.
#
# 5/5: |Thundertooth Part 1.docx| Source 5:
# As the news of Thundertooth's arrival spread, the city embraced the talking dinosaur as a symbol of unity between the past and the future. Thundertooth found a new home in the city's park, where holographic flowers bloomed, and the citizens marveled at the beauty of coexistence across time. And so, in this extraordinary city of flying cars and advanced technology, Thundertooth became a beloved figure, a living bridge between eras, teaching the people that understanding and cooperation could overcome even the greatest challenges.
#
#
# 4/4: Did anything eventful happen?
# llama_print_timings:        load time =    2293.84 ms
# llama_print_timings:      sample time =      43.06 ms /   156 runs   (    0.28 ms per token,  3623.02 tokens per second)
# llama_print_timings: prompt eval time =    7355.09 ms /  1086 tokens (    6.77 ms per token,   147.65 tokens per second)
# llama_print_timings:        eval time =   14203.57 ms /   155 runs   (   91.64 ms per token,    10.91 tokens per second)
# llama_print_timings:       total time =   21912.05 ms
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Llama.generate: prefix-match hit
# 1/4: |Thundertooth Part 1.docx| Source 1:
# "Hello there, majestic creature. What brings you to our time?" Mayor Grace inquired, her voice calm and reassuring.
#
#
#
# Thundertooth, though initially startled, found comfort in the mayor's soothing tone. In broken sentences, he explained his journey through time, the strange portal, and his hunger dilemma. Mayor Grace listened intently, her eyes widening with amazement at the tale of the prehistoric dinosaur navigating the future.
#
#
#
# Realizing the dinosaur's predicament, Mayor Grace extended an invitation. "You are welcome in our city, Thundertooth. We can find a way to provide for you without causing harm to anyone. Let us work together to find a solution."
#
#
#
# Grateful for the mayor's hospitality, Thundertooth followed her through the city. Together, they explored the futuristic marketplaces and innovative food labs, eventually discovering a sustainable solution that satisfied the dinosaur's hunger without compromising the well-being of the city's inhabitants.
#
# 2/4: |Thundertooth Part 1.docx| Source 2:
# "Hello there, majestic creature. What brings you to our time?" Mayor Grace inquired, her voice calm and reassuring.
#
#
#
# Thundertooth, though initially startled, found comfort in the mayor's soothing tone. In broken sentences, he explained his journey through time, the strange portal, and his hunger dilemma. Mayor Grace listened intently, her eyes widening with amazement at the tale of the prehistoric dinosaur navigating the future.
#
#
#
# Realizing the dinosaur's predicament, Mayor Grace extended an invitation. "You are welcome in our city, Thundertooth. We can find a way to provide for you without causing harm to anyone. Let us work together to find a solution."
#
#
#
# Grateful for the mayor's hospitality, Thundertooth followed her through the city. Together, they explored the futuristic marketplaces and innovative food labs, eventually discovering a sustainable solution that satisfied the dinosaur's hunger without compromising the well-being of the city's inhabitants.
#
# 3/4: |Thundertooth Part 1.docx| Source 3:
# As the news of Thundertooth's arrival spread, the city embraced the talking dinosaur as a symbol of unity between the past and the future. Thundertooth found a new home in the city's park, where holographic flowers bloomed, and the citizens marveled at the beauty of coexistence across time. And so, in this extraordinary city of flying cars and advanced technology, Thundertooth became a beloved figure, a living bridge between eras, teaching the people that understanding and cooperation could overcome even the greatest challenges.
#
# 4/4: |Thundertooth Part 3.docx| Source 4:
# The mayor, recognizing Thundertooth's intelligence and resourcefulness, approached him. "Thundertooth, we need a plan to divert or neutralize the meteor. Our technology can only do so much, but with your unique abilities, perhaps we can find a solution."
#
#
#
# Thundertooth nodded, understanding the gravity of the situation. He gathered Lumina, Echo, Sapphire, and Ignis, explaining the urgency and the role each of them would play in the impending crisis.
#
#
#
# 1. **Lumina**: Utilizing her deep understanding of technology, Lumina would enhance the city's energy systems to generate a powerful force field, providing a protective barrier against the meteor's impact.
#
#
#
# 2. **Echo**: With his extraordinary mimicry abilities, Echo would amplify the emergency signals, ensuring that every citizen received timely warnings and instructions for evacuation.
#
#
#
# 3. **Sapphire**: Harnessing her calming and healing powers, Sapphire would assist in calming the panicked masses, ensuring an orderly and efficient evacuation.
#
#
#
# 4. **Ignis**: Drawing upon his fiery talents, Ignis would create controlled bursts of heat, attempting to alter the meteor's trajectory and reduce its destructive force.
# llama_print_timings:        load time =    2293.84 ms
# llama_print_timings:      sample time =      91.54 ms /   325 runs   (    0.28 ms per token,  3550.36 tokens per second)
# llama_print_timings: prompt eval time =    8066.00 ms /  1049 tokens (    7.69 ms per token,   130.05 tokens per second)
# llama_print_timings:        eval time =   30532.97 ms /   324 runs   (   94.24 ms per token,    10.61 tokens per second)
# llama_print_timings:       total time =   39373.70 ms

# %% [markdown]
# #### 13. Output responses

# %%
for index, (question, answer) in enumerate(qa_pairs, start=1):
    print(f"{index}/{len(qa_pairs)} {question}\n\n{answer}\n\n--------\n")
# Out:
# 1/4 Summarise the story for me
#
# In this captivating tale, we encounter Thundertooth, a prehistoric dinosaur who is mysteriously transported through time and finds himself in a futuristic city. Upon his arrival, he encounters Mayor Grace, who warmly welcomes him despite the astonishment of such an unexpected visitor. Thundertooth shares his incredible journey and expresses his concern about finding food as a carnivorous dinosaur in this modern setting.
#
# Mayor Grace, showing empathy and understanding, assures Thundertooth that he is safe within her city's boundaries and they will work together to find a solution for his hunger without causing harm to the citizens. They explore advanced food labs and futuristic marketplaces, eventually discovering a sustainable way to satisfy Thundertooth's needs.
#
# As news of Thundertooth's arrival spreads, the city embraces him as a symbol of unity between past and future. He becomes an integral part of the community, living in the park where holographic flowers bloom, and people marvel at the beauty of coexistence across time.
#
# Later on, when faced with an impending threat from a meteor, Thundertooth joins forces with other extraordinary beings - Lumina, Echo, Sapphire, and Ignis - to devise a plan for its diversion or neutralization. Each of them uses their unique abilities to protect the city: Lumina enhances energy systems, Echo amplifies emergency signals, Sapphire calms the masses during evacuation, and Ignis creates controlled bursts of heat to alter the meteor's trajectory.
#
# In summary, this story is about Thundertooth's journey through time, his acceptance in a futuristic society, and his role as an instrumental figure in uniting different eras while working together with other extraordinary beings to overcome challenges that threaten their newfound home.
#
# --------
#
# 2/4 Who was the main protagonist?
#
# In this particular context provided, we do not have enough information to identify a specific main protagonist. The given sources discuss various events and characters, such as Thundertooth, Mayor Grace, Lumina, Echo, Sapphire, Ignis, and others. However, without further details or a clear narrative, it is impossible for me to determine the primary character in these excerpts.
#
# --------
#
# 3/4 Did they have any children? If so, what were their names?
#
# Indeed, they did have children. Their family grew over time as a testament to their love and commitment to each other. The firstborn was a bright and curious child named Lumina, who inherited her parents' intelligence and sense of wonder. Following Lumina came Echo, the second-born with an exceptional gift for mimicry that brought joy and entertainment to everyone around him. Sapphire, the third sibling, possessed healing abilities and a calming presence that made her a natural caregiver among her family and friends. Each child carried unique traits that reflected their parents' qualities as well as the diverse world they were growing up in. Their family became an example of unity between generations and a symbol of hope for future families to come.
#
# --------
#
# 4/4 Did anything eventful happen?
#
# Indeed, several eventful occurrences took place within the given context. Firstly, there was the captivating story of Thundertooth, a prehistoric dinosaur who found himself transported through time to a futuristic city. This encounter between the past and the future led to an incredible display of hospitality from Mayor Grace, who welcomed Thundertooth into her city and helped him find a sustainable solution for his hunger without causing harm to anyone.
#
# Moreover, the news of Thundertooth's arrival sparked unity among the citizens, as they embraced the talking dinosaur as a symbol of their bond across time. This led to Thundertooth becoming an integral part of the city and even earning a place in its park where he continued to teach people about cooperation and understanding.
#
# Later on, another eventful situation unfolded when the city faced a grave threat from an incoming meteor. In response, Mayor Grace turned to Thundertooth for help, recognizing his intelligence and resourcefulness. Along with other companions - Lumina, Echo, Sapphire, and Ignis - they devised a plan to protect their city by enhancing energy systems, amplifying emergency signals, calming the masses, and altering the meteor's trajectory.
#
# In summary, the story is filled with eventful moments that showcase the power of cooperation between different eras, as well as the determination and resilience of both humans and prehistoric creatures in facing challenges together.
#
# --------
