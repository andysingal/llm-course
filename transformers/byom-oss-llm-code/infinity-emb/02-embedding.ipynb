# %% [markdown]
# ### Introduction
# In this notebook, we will test out pulling out a [nreimers/MiniLM-L6-H384-uncased](https://huggingface.co/nreimers/MiniLM-L6-H384-uncased) and serving with [Infinity](https://michaelfeil.eu/infinity/latest/) in SAP AI Core. Subsequently, we will use the embedding model and work with SAP HANA Cloud Vector Engine to store the embeddings (Note: bge-small-en uses dimension of 384). After which, we will show you how to perform similarity search function as well.
#
# ### Prerequisites
# Before running this notebook, please assure you have performed the [Prerequisites](../../README.md) and [01-deployment.ipynb](01-deployment.ipynb). As a result, a deployment of Infinity scenario is running in SAP AI Core.<br/><br/>
#
# If the configuration and deployment are created through SAP AI Launchpad, please manually update the configuration_id and deployment_id in [env.json](env.json)
# ```json
# {
#     "configuration_id": "<YOUR_CONFIGURATION_ID_OF_INFINITY_SCENARIO>",
#     "deployment_id": "<YOUR_DEPLOYMENT_ID_BASED_ON_CONFIG_ABOVE>"
# }
# ```
#
# ### The high-level flow:
# 1. Load configurations info
# 2. Connect to SAP AI Core via SDK
# 3. Check the status and logs of the deployment
# 4. Inference against the Infinity server through SAP AI Core
# 5. Using Infinity to generate embeddings to store in SAP HANA Cloud Vector Engine
# 6. Perform Similarity Search using Infinity > bge-small-en embedding model with SAP HANA Cloud Vector Engine

# %% [markdown]
# #### 1. Load config info
# - resource_group loaded from [config.json](../config.json)
# - deployment_id(created in 01-deployment.ipynb) loaded [env.json](env.json)

# %%
import requests, json
from ai_core_sdk.ai_core_v2_client import AICoreV2Client

# %%
# Please replace the configurations below.
# config_id: The target configuration to create the deployment. Please create the configuration first.
with open("../config.json") as f:
    config = json.load(f)

with open("./env.json") as f:
    env = json.load(f)

deployment_id = env["deployment_id"]
resource_group = config.get("resource_group", "default")
print("deployment id: ", deployment_id, " resource group: ", resource_group)
# Out:
# deployment id:  d98287077fa69df2  resource group:  oss-llm

# %% [markdown]
# #### 2. Initiate connection to SAP AI Core

# %%
# Initiate an AI Core SDK client with the information of service key
ai_core_sk = config["ai_core_service_key"]
base_url = ai_core_sk.get("serviceurls").get("AI_API_URL") + "/v2/lm"
ai_core_client = AICoreV2Client(base_url=ai_core_sk.get("serviceurls").get("AI_API_URL")+"/v2",
                        auth_url=ai_core_sk.get("url")+"/oauth/token",
                        client_id=ai_core_sk.get("clientid"),
                        client_secret=ai_core_sk.get("clientsecret"),
                        resource_group=resource_group)

# %%
token = ai_core_client.rest_client.get_token()
headers = {
        "Authorization": token,
        'ai-resource-group': resource_group,
        "Content-Type": "application/json"}

# %% [markdown]
# #### 3. Check the deployment status

# %%
# Check deployment status before inference request
deployment_url = f"{base_url}/deployments/{deployment_id}"
response = requests.get(url=deployment_url, headers=headers)
resp = response.json()    
status = resp['status']

deployment_log_url = f"{base_url}/deployments/{deployment_id}/logs"
if status == "RUNNING":
        print(f"Deployment-{deployment_id} is running. Ready for inference request")
else:
        print(f"Deployment-{deployment_id} status: {status}. Not yet ready for inference request")
        #retrieve deployment logs
        #{{apiurl}}/v2/lm/deployments/{{deploymentid}}/logs.

        response = requests.get(deployment_log_url, headers=headers)
        print('Deployment Logs:\n', response.text)
# Out:
# Deployment-d98287077fa69df2 is running. Ready for inference request

# %% [markdown]
# #### 4. Inference against the Infinity Server

# %%
deployment = ai_api_client.deployment.get(deployment_id)
inference_base_url = f"{deployment.deployment_url}"
print(inference_base_url)
# Out:
# https://api.ai.prod.eu-central-1.aws.ml.hana.ondemand.com/v2/inference/deployments/d98287077fa69df2

# %%
# GET Models
model_endpoint = f"{inference_base_url}/v1/models"
print(model_endpoint)

response = requests.get(model_endpoint, headers=headers)
print('Result:', response.text)
# Out:
# https://api.ai.prod.eu-central-1.aws.ml.hana.ondemand.com/v2/inference/deployments/d98287077fa69df2/v1/models
# Result: {"data":[{"id":"nreimers/MiniLM-L6-H384-uncased","stats":{"queue_fraction":0.0,"queue_absolute":0,"results_pending":0,"batch_size":32},"object":"model","owned_by":"infinity","created":1716522442,"backend":"torch"}],"object":"list"}

# %%
# POST Embeddings
endpoint = f"{inference_base_url}/v1/embeddings"
print(endpoint)

json_data = {
  "input": [
    "A sentence to encode."
  ]
}

response = requests.post(endpoint, headers=headers, json=json_data)
x = json.loads(response.content)
print(x['data'][0]['embedding'])
# Out:
# https://api.ai.prod.eu-central-1.aws.ml.hana.ondemand.com/v2/inference/deployments/d98287077fa69df2/v1/embeddings
# [-0.0741010531783104, 0.05380121245980263, -0.02237294614315033, 0.00028090568957850337, -0.050218887627124786, -0.024147523567080498, 0.11244519799947739, 0.032124828547239304, 0.012422042898833752, 0.015622916631400585, 0.019686201587319374, -0.02363339252769947, 0.022356361150741577, 0.033401861786842346, 0.01734774000942707, 0.0017942721024155617, -0.003283797763288021, 0.09778419882059097, -0.03288773074746132, -0.03315309062600136, 0.028210807591676712, 0.02099640481173992, -0.0003472450189292431, -0.014810259453952312, 0.03545838221907616, 0.020764216780662537, 0.015117079019546509, 0.00610321993008256, 0.07887748628854752, -0.16027586162090302, -0.006538572255522013, 0.028426410630345345, -0.010266014374792576, -0.003874632529914379, 0.02772984839975834, 0.01971937157213688, 0.0062027289532125, 0.042059145867824554, -0.016385819762945175, 0.0046769240871071815, 0.00642247823998332, 0.018624773249030113, -0.012314241379499435, 0.0006939718150533736, 0.01369907520711422, -0.006816368084400892, 0.015274635516107082, 0.00237577804364264, -0.010904530994594097, 0.016261432319879532, -0.004647900816053152, -0.0005390071892179549, -0.05705184116959572, 0.031478021293878555, 0.005257393233478069, 0.021427609026432037, 0.022256851196289062, 0.00990114826709032, 0.032920900732278824, 0.00796486809849739, -0.0022099295165389776, 0.004048773553222418, -0.19742590188980103, 0.17765678465366364, 0.033401861786842346, -0.010630880482494831, 0.014229790307581425, -0.004618877079337835, -0.06740077584981918, 0.06720176339149475, 0.01386492419987917, 0.01652679033577442, 0.01409711129963398, 0.03237360343337059, 0.006281507201492786, 0.0023612661752849817, -0.02157687395811081, 0.028044959530234337, 0.014254667796194553, -0.002958320314064622, 0.00724757369607687, -0.007181234657764435, -0.032075073570013046, 0.02952101081609726, -0.015987783670425415, 0.013649321161210537, -0.0018782328115776181, -0.022472454234957695, 0.004635462071746588, -0.02104615792632103, -0.017181891947984695, -0.02044910378754139, -0.023666562512516975, 0.02170955203473568, -0.03953825309872627, 0.029089804738759995, 0.043916650116443634, 0.0012480090372264385, -0.01661800779402256, 0.2523548901081085, -0.031212663277983665, 0.01754675805568695, 0.010589418932795525, -0.0162199717015028, -0.011642555706202984, -0.0040840161964297295, 0.009469942189753056, -0.00791096780449152, 0.009196292608976364, -0.004357666242867708, 0.00162531400565058, 0.0035843979567289352, 0.05897568166255951, -0.03668566048145294, 0.01932133547961712, 0.007604147773236036, 0.025325046852231026, 0.006211021449416876, 0.04113039746880531, -0.032920900732278824, -0.0009038736461661756, 0.005025205668061972, -0.046769242733716965, 0.011601094156503677, -0.014146866276860237, -0.08053597062826157, 0.04122990742325783, 0.01599607616662979, -0.00128739804495126, -0.008139008656144142, 0.05045107379555702, -0.01748041808605194, 0.0014895256608724594, 0.01035723090171814, 0.004975451156497002, 0.0010546919656917453, -0.032937485724687576, -0.004169013351202011, -0.011227934621274471, -0.0055973827838897705, -0.007164649665355682, -0.03744856268167496, 0.011999130249023438, -0.012811786495149136, 0.006538572255522013, 0.20206965506076813, -0.0010966723784804344, 0.023251941427588463, -0.02137785591185093, -0.00627321470528841, -0.029769783839583397, 0.008072669617831707, 0.015282928012311459, -0.0016895802691578865, -0.028376657515764236, -0.017696021124720573, 0.05141299590468407, 0.22688058018684387, -0.03363405168056488, 0.014113696292042732, -0.03993628919124603, -0.0009152757120318711, -0.005211784970015287, 0.1382512003183365, 0.018508678302168846, 0.008872888050973415, 0.022887075319886208, -0.022008080035448074, -0.0026805242523550987, 0.027696678414940834, 0.01641898974776268, 0.0004242090508341789, 3.835243478533812e-05, -0.001286361482925713, 0.019304750487208366, 0.024263616651296616, 0.030814627185463905, 0.03355112671852112, 0.01774577610194683, 0.006542718503624201, -0.0071895271 ...

# %% [markdown]
# #### 5. Using Infinity to generate embeddings to store in SAP HANA Cloud Vector Engine

# %%
# Import required libraries
import pandas as pd
import hana_ml
print(pd.__version__)
print(hana_ml.__version__)
# Out:
# 2.2.1
# 2.19.24022101

# %%
# 5.1 Create NEW Table for this sample
# Connect to SAP HANA Cloud Vector Engine with hana_ml library
# sa-gen-ai-enablement subaccount
# 6d585c73-26bf-4f19-ae2b-54f3d7e01edf.hna0.prod-eu10.hanacloud.ondemand.com

from hana_ml import ConnectionContext
cc= ConnectionContext(
    address='6d585c73-26bf-4f19-ae2b-54f3d7e01edf.hna0.prod-eu10.hanacloud.ondemand.com', 
    port='443', 
    user='DBADMIN', 
    password='zxCV12#$', 
    encrypt=True
    )
print(cc.hana_version())
print(cc.get_current_schema())
# Out:
# 4.00.000.00.1712176279 (fa/CE2024.2)
# DBADMIN

# %%
# 5.2 get a csv file into pandas df
# Note: At the time of testing, ensure that the records are not already in the table.

df = pd.read_csv('./social_data.csv', sep=',', quotechar='"', low_memory=False)
df.head(80)
# Out:
#     ID  PROCESSOR PROCESSDATE PROCESSTIME         REPORTEDBY    DECISION  \
# 0   11  processor    2024-3-9    17:55:47         Mosty_2024  unattended
# 1   12  processor    2024-3-9    17:56:23         Mosty_2024    notified
# 2   13  processor   2024-3-13    16:39:54         Mosty_2024    notified
# 3   14  processor   2024-3-13    16:40:33         jacobtan89    notified
# 4   15  processor   2024-3-13    16:40:50         jacobtan89    notified
# ..  ..        ...         ...         ...                ...         ...
# 58  69  processor   2024-3-14    08:20:32        Trinidad_MG    notified
# 59  70  processor   2024-3-19    20:35:53  BraveDistrict4961    notified
# 60  71  processor   2024-3-19    20:36:32              btpsa    notified
# 61  72  processor   2024-3-19    23:44:46          Eddy_2024    notified
# 62  73  processor   2024-3-19    23:45:18          Eddy_2024    notified
#
#    REDDITPOSTID  MAINTENANCENOTIFICATIONID                         ADDRESS  \
# 0       1ap34of                        NaN                27-3 Victoria Rd
# 1       1ao2ui7                 10000320.0                       High Road
# 2       1aisbj2                 10000321.0                27-3 Victoria Rd
# 3       1amjanl                 10000322.0                     Albert Road
# 4       1amj9zl                 10000323.0                  Hollybush Hill
# ..          ...                        ...                             ...
# 58      1aeqluz                 10000377.0  High Road and Grove Green Road
# 59      1ads7xz                 10000410.0                       High Road
# 60      1biuf9w                 10000411.0                       High Road
# 61      1biz4rp                 10000412.0                       High Road
# 62      1biyzr4                 10000413.0                       High Road
#
#                                     LOCATION  ...  \
# 0   51.553842239632296,0.0041263312666776075  ...
# 1     51.56570052194053,0.015960105979618958  ...
# 2   51.553842239632296,0.0041263312666776075  ...
# 3      51.5512072970387,0.009166761817106052  ...
# 4   51.572192085954335,-0.030992827179612173  ...
# ..                                       ...  ...
# 58  51.56695925174642, -0.006486404268305011  ...
# 59  51.56438148195644, -0.012273466333225048  ...
# 60                              float, float  ...
# 61                              float, float  ...
# 62                              float, float  ...
#
#                                      GENAIDESCRIPTION PRIORITY PRIORITYDESC  \
# 0   An overflowing dustbin at 27-3 Victoria Rd, Lo...        3       medium
# 1   The public area in front of Sagenai Park on Hi...        3       medium
# 2   An overflowing dustbin at 27-3 Victoria Rd, Lo...        3       medium
# 3   There is a bulky waste left in the common area...        3       medium
# 4   The grass in the beautiful park on Hollybush H...        3       medium
# ..                                                ...      ...          ...
# 58  A potential mosquito breeding site has been di...        3       medium
# 59  A massive fallen tree in the middle of Grove P...        3       medium
# 60  A massive fallen tree in the middle of Grove P...        2         high
# 61  There's a pot hole on High Road, near the junc...        2         high
# 62  There's a pot hole on High Road, near the junc...        2         high
#
#    SENTIMENT                     CATEGORY        DATE      TIME  \
# 0    NEUTRAL           PUBLIC CLEANLINESS  2024-02-12  15:52:51
# 1    NEUTRAL           PUBLIC CLEANLINESS  2024-02-11  07:55:41
# 2    NEUTRAL           PUBLIC CLEANLINESS  2024-02-04  16:50:35
# 3   NEGATIVE           PUBLIC CLEANLINESS  2024-02-09  08:10:53
# 4    NEUTRAL  FACILITY & PARK MAINTENANCE  2024-02-09  08:09:37
# ..       ...                          ...         ...       ...
# 58  NEGATIVE                        PESTS  2024-01-30  15:10:51
# 59  NEGATIVE  FACILITY & PARK MAINTENANCE  2024-01-29  10:27:28
# 60  NEGATIVE  FACILITY & PARK MAINTENANCE  2024-03-19  20:30:35
# 61   NEUTRAL            ROADS & FOOTPATHS  2024-03-19  23:40:10
# 62   NEUTRAL            ROADS & FOOTPATHS  2024-03-19  23:34:20
#
#                                                  TEXT  \
# 0   Urgent Announcement for Public Attention! Dear...
# 1   Attention Sagenai residents! 📍\n\nI hope this ...
# 2   📢 Urgent Report for Public Attention 📢\n\n&amp...
# 3   📢 Hey fellow Sagenai residents! 🏡🌳\n\n&amp;#x2...
# 4   📢 Attention Sagenai residents! 📍\n\n&amp;#x200...
# ..                                                ...
# 58  🚨URGENT🚨 Hey, Sagenai!   \nI'm so thrilled to ...
# 59  🚨🌳NOT SO SAFE PARK ALERT!🌳🚨\n\nHey u/SagenaiCo...
# 60  **🚨🌳NOT SO SAFE PARK ALERT!🌳🚨Hey** u/SagenaiCo...
# 61  📢 Attention residents of Sagenai! 🚧I hope this...
# 62  📢 Attention residents of Sagenai! 🚧I hope this...
#
#                                             EMBEDDING  \
# 0   [0.018654607236385345, 0.002410407643765211, -...
# 1   [0.022811686620116234, 0.01718984916806221, 0....
# 2   [0.017875781282782555, -0.001261840108782053, ...
# 3   [0.02464723028242588, 0.004297903273254633, 0....
# 4   [0.007574773393571377, 0.004422580823302269, 0...
# ..                                                ...
# 58                                                NaN
# 59                                                NaN
# 60                                                NaN
# 61                                                NaN
# 62                                                NaN
#
#                                                VECTOR
# 0   000600008CD1983CEEF71D3BA42397BBF8A4F73BAACEB4...
# 1   0006000093DFBA3CBAD18C3C9A70193CCB3DEE3B5A4BC1...
# 2   000600003B70923C5464A5BADD7F2CBB511DBF3A87B9C2...
# 3   00060000FDE8C93C6DD58C3BF115643BAA62AD3B0D94B9...
# 4   00060000CE35F83B4CEB903B1616313C3C465DBC687405...
# ..                                                ...
# 58                                                NaN
# 59                                                NaN
# 60                                                NaN
# 61                                                NaN
# 62                                                NaN
#
# [63 rows x 23 columns]

# %%
# 5.3 SELECT query to HDI container's table to ensure connection context works

hdf = cc.sql('''SELECT TOP 10 "ID", "TEXT", "VECTOR" FROM SOCIAL_CITIZEN_GENAI_PROCESSEDISSUES''')
df_abstract = hdf.collect()
print(df_abstract)
# Out:
# Empty DataFrame
# Columns: [ID, TEXT, VECTOR]
# Index: []

# %%
# 5.4 Embedding method - using open source embedding model

def get_embedding(input) -> str: 
    endpoint = f"{inference_base_url}/v1/embeddings"
    # print(endpoint)
    json_data = {
      "input": [
        input
      ]
    }
    response = requests.post(endpoint, headers=headers, json=json_data)
    x = json.loads(response.content)
    return x['data'][0]['embedding']

# %%
# 5.5 Drop table if already exists

# cursor = cc.connection.cursor()
# sql_command = '''DROP TABLE SOCIAL_CITIZEN_GENAI_PROCESSEDISSUES;'''
# cursor.execute(sql_command)
# cursor.close()

# %%
# 5.6 Create a table

cursor = cc.connection.cursor()
sql_command = '''CREATE TABLE SOCIAL_CITIZEN_GENAI_PROCESSEDISSUES(ID INTEGER, PROCESSOR NVARCHAR(5000), PROCESSDATE NVARCHAR(5000), PROCESSTIME NVARCHAR(5000), REPORTEDBY NVARCHAR(5000), DECISION NVARCHAR(5000), REDDITPOSTID NVARCHAR(5000), MAINTENANCENOTIFICATIONID NVARCHAR(5000), ADDRESS NVARCHAR(5000), LOCATION NVARCHAR(5000), LAT NVARCHAR(5000), LONG NVARCHAR(5000), GENAISUMMARY NVARCHAR(5000), GENAIDESCRIPTION NVARCHAR(5000), PRIORITY NVARCHAR(5000), PRIORITYDESC NVARCHAR(5000), SENTIMENT NVARCHAR(5000), CATEGORY NVARCHAR(5000), DATE DATE, TIME NVARCHAR(5000), TEXT NVARCHAR(5000), EMBEDDING NCLOB);'''
cursor.execute(sql_command)
cursor.close()

# %%
# 5.7 Add REAL_VECTOR column
# Note: here you define the dimension that suits to the model you're using
# e.g. nreimers/MiniLM-L6-H384-uncased uses dimension of 384
# https://www.sbert.net/docs/pretrained_models.html

cursor = cc.connection.cursor()
sql_command = '''ALTER TABLE SOCIAL_CITIZEN_GENAI_PROCESSEDISSUES ADD (VECTOR REAL_VECTOR(384));'''
cursor.execute(sql_command)
cursor.close()

# %%
# 5.8 prepare rows to be bulk insert
# generate embeddings from the text

import math
rows = []
for index, row in df.iterrows():
    data_to_insert = row.to_dict()
    text=row.TEXT
    x=row.MAINTENANCENOTIFICATIONID

    # check on maintenance notification id as some values are NaN
    if math.isnan(x):
        maintenanceNotID=0
    else:
        maintenanceNotID=row.MAINTENANCENOTIFICATIONID
    
    text_vector = get_embedding(input=text)
    
    myrow = (row['ID'], row['PROCESSOR'], row['PROCESSDATE'], row['PROCESSTIME'], row['REPORTEDBY'], row['DECISION'], 
             row['REDDITPOSTID'], maintenanceNotID, row['ADDRESS'], row['LOCATION'], row['LAT'], 
             row['LONG'], row['GENAISUMMARY'], row['GENAIDESCRIPTION'], row['PRIORITY'], row['PRIORITYDESC'], row['SENTIMENT'], 
             row['CATEGORY'], row['DATE'], row['TIME'], row['TEXT'], str(text_vector), str(text_vector))
    
    rows.append(myrow)
# print(myrow)

# %%
# 5.9 bulk insert of 23 fields parameterised in rows variable
# for more details of the dimension for the model, refer to https://huggingface.co/nreimers/MiniLM-L6-H384-uncased
# nreimers/MiniLM-L6-H384-uncased model has dimension of 384, thus mismatched with the dimension you've defined for the vector column in SAP HANA Cloud Vector Database

cc.connection.setautocommit(False)
cursor = cc.connection.cursor()
sql = '''INSERT INTO SOCIAL_CITIZEN_GENAI_PROCESSEDISSUES 
VALUES(?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,TO_REAL_VECTOR(?));'''
try:
    cursor.executemany(sql, rows)
except Exception as e:
    cc.connection.rollback()
    print("An error occurred:", e)
try:
    cc.connection.commit()
finally:
    cursor.close()
cc.connection.setautocommit(True)

# %% [markdown]
# #### 6. Perform Similarity Search using Infinity > bge-small-en embedding model with SAP HANA Cloud Vector Engine

# %%
# 6.1 Define a run_vector_search with metric and query as input parameters

def run_vector_search(query: str, metric="COSINE_SIMILARITY", k=4):
    if metric == 'L2DISTANCE':
        sort = 'ASC'
    else:
        sort = 'DESC'
    query_vector = get_embedding(input=query)
    sql = '''SELECT TOP {k} "ID", "CATEGORY", "TEXT", "DATE", "LOCATION", "{metric}"("VECTOR", TO_REAL_VECTOR('{qv}')) AS SIM
        FROM "DBADMIN"."SOCIAL_CITIZEN_GENAI_PROCESSEDISSUES"
        ORDER BY "SIM" {sort}'''.format(k=k, metric=metric, qv=query_vector, sort=sort)
    hdf = cc.sql(sql)
    df_context = hdf.head(k).collect()
    return df_context

# %%
# 6.1 Prepare a text string to be used as input for the similarity search

vector_str = """📢 Urgent Report for Public Attention 📢

Dear neighbours of Sagenai,

I hope this post finds you well. I am writing today to bring to your attention a pressing issue that requires immediate action from our local authorities. 🚮

In the heart of our beautiful neighbourhood, specifically at 27-3 Victoria Rd, London, UK, we are currently facing a problem that greatly affects our daily lives: an overflowing dustbin. 🗑️ The pungent odor, unsightly sight, and the potential for vermin and health hazards pose a significant inconvenience for all of us. 🤢

I kindly request our esteemed local administration to address this matter promptly, ensuring the cleanliness and hygiene we deserve in our shared spaces. 🙏🏼 Let's work together to maintain the charm and cleanliness of our beloved Sagenai!

Thank you for your attention and support in resolving this matter.

Best regards,

Concerned Citizen 🌟

Coordinates:(51.553842239632296,0.0041263312666776075)

&amp;#x200B;

https://preview.redd.it/8f6f8tumw"""

# %%
# 6.3 Perform the similarity search and print out k number of similar search results

df = run_vector_search(query = vector_str, k = 10)
df
# Out:
#     ID            CATEGORY                                               TEXT  \
# 0   26  PUBLIC CLEANLINESS  📢 Urgent Report for Public Attention 📢\n\nDear...
# 1   13  PUBLIC CLEANLINESS  📢 Urgent Report for Public Attention 📢\n\n&amp...
# 2   40  PUBLIC CLEANLINESS  📢 Attention Sagenai residents! 📢\n\n&amp;#x200...
# 3   59  PUBLIC CLEANLINESS  📢 Attention fellow Sagenai residents! 🏡\n\n&am...
# 4   11  PUBLIC CLEANLINESS  Urgent Announcement for Public Attention! Dear...
# 5  999  PUBLIC CLEANLINESS  Urgent Announcement for Public Attention! Dear...
# 6   34  PUBLIC CLEANLINESS  📣 Attention fellow Sagenai residents! 📣\n\nI h...
# 7   65  PUBLIC CLEANLINESS  Hey everyone! 👋 I wanted to bring up a little ...
# 8   47  PUBLIC CLEANLINESS  I hope this message finds you well. 😊 However,...
# 9   67     DRAINS & SEWERS  📢 Urgent Public Announcement 📢\n\n&amp;#x200B;...
#
#          DATE                                   LOCATION       SIM
# 0  2024-02-03   51.553842239632296,0.0041263312666776075  1.000000
# 1  2024-02-04   51.553842239632296,0.0041263312666776075  0.988930
# 2  2024-02-01     51.564875435684534,0.01679572596184302  0.947843
# 3  2024-01-31   51.57190697091999, -0.028626163737301077  0.944420
# 4  2024-02-12   51.553842239632296,0.0041263312666776075  0.921868
# 5  2024-02-12   51.553842239632296,0.0041263312666776075  0.921868
# 6  2024-02-02   51.564562910897315,-0.018637765272000048  0.902331
# 7  2024-01-30     51.56232633931576,0.004961210312297189  0.901116
# 8  2024-02-01      51.5728533044047,-0.03229501754130372  0.895889
# 9  2024-01-30  51.563772772936154, -0.010011597090067229  0.894030
