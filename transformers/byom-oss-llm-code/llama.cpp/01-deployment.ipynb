# %% [markdown]
# ### Introduction
# This notebook illustrates and automates the Continuous Deployment process for bringing the popular open-source large language models backend [llama.cpp](https://github.com/ggerganov/llama.cpp) into SAP AI Core. Running LLaMa 3, Phi3, Mistral, Mixtral, LlaVA, and other [supported models in llama.cpp](https://github.com/ggerganov/llama.cpp) in SAP AI Core through BYOM(Bring Your Own Model) approach. <br/>
#
# ### Prerequisites
# Before running this notebook, please assure you have perform the [Prerequisites](../../README.md)<br/><br/>
#
# If the configuration of llama.cpp scenario is created through SAP AI Launchpad instead of running [00-init-config.ipynb](../00-init-config.ipynb), please manually update the configuration_id in [env.json](env.json)
# ```json
# {
#     "configuration_id": "<YOUR_CONFIGURATION_ID_OF_LLAMA.CPP_SCENARIO>",
#     "deployment_id": "<WILL_BE_UPDATED_BY_THIS_NOTEBOOK>"
# }
# ```
#
# ### The high-level flow of this Continuous Deployment process:
# - Build a custom docker image adapted for SAP AI Core<br/>
# - Push the docker image to docker hub<br/>
# - Connect to SAP AI Core via SDK<br/>
# - Create a deployment<br/>
# - Check the status and logs of the deployment<br/>

# %% [markdown]
# #### 1.Build a custom docker image adapted for SAP AI Core
# Please refer to [Dockerfile](Dockerfile) for details.

# %%
# %%sh
# # 0.Login to docker hub
# docker login -u <YOUR_DOCKER_USER> -p <YOUR_DOCKER_ACCESS_TOKEN>
#
# # 1.Build the docker image
# docker build \
# 		--platform=linux/amd64 \
# 		-t docker.io/<YOUR_DOCKER_USER>/llama.cpp-server:ai-core .

# %% [markdown]
# #### 2.Push the docker image to docker hub

# %%
# %%sh
# # 2.Push the docker image to docker hub to be used by deployment in SAP AI Core
# docker push docker.io/<YOUR_DOCKER_USER>/llama.cpp-server:ai-core

# %% [markdown]
# #### 3.Initiate an SAP AI Core SDK client
# - resource_group loaded from [../config.json](../config.json)
# - ai_core_sk(service key) loaded from [../config.json](../config.json)

# %%
import requests, json, time, datetime
from datetime import datetime
from ai_core_sdk.ai_core_v2_client import AICoreV2Client

# %%
# load the configuration from ../config.json 
with open("../config.json") as f:
    config = json.load(f)

resource_group = config.get("resource_group", "default")
print( "resource group: ", resource_group)
# Out:
# resource group:  oss-llm

# %%
# Initiate an AI Core SDK client with the information of service key
ai_core_sk = config["ai_core_service_key"]
base_url = ai_core_sk.get("serviceurls").get("AI_API_URL") + "/v2/lm"
client = AICoreV2Client(base_url=ai_core_sk.get("serviceurls").get("AI_API_URL")+"/v2",
                        auth_url=ai_core_sk.get("url")+"/oauth/token",
                        client_id=ai_core_sk.get("clientid"),
                        client_secret=ai_core_sk.get("clientsecret"),
                        resource_group=resource_group)

# %%
# Prepare the http header which will be used later through request.
token = client.rest_client.get_token()
headers = {
    "Authorization": token,
    "ai-resource-group": resource_group,
    "Content-Type": "application/json",
}

# %% [markdown]
# #### 4.Create a deployment for llama.cpp scenario
# To create a deployment in SAP AI Core, it requires the corresponding resource_group and configuration_id
# - resource_group loaded from [../config.json](../config.json)
# - configuration_id of  loaded from [env.json](env.json)

# %%
# resource_group: The target resource group to create the deployment
# configuration_id: The target configuration to create the deployment, which is created in ../00-init-config.ipynb 
with open("./env.json") as f:
    env = json.load(f)

configuration_id = env["configuration_id"]
print("configuration id:", configuration_id)
# Out:
# configuration id: 33a87ba9-48e1-431c-b963-282665428ca4

# %% [markdown]
# **Helper function**
# - get the current UTC time in yyyy-mm-dd hh:mm:ss format, to be used to filter deployments logs

# %%
# Helper function to get the current time in UTC, used to filter deployments logs
def get_current_time():  
    current_time = datetime.utcnow()
    # Format current time in the desired format
    formatted_time = current_time.strftime("%Y-%m-%dT%H:%M:%S.%fZ")
    return formatted_time

# %% [markdown]
# **Helper function**
# - Write back the configuration value back to configuration json file

# %%
# Helper function to write back the configuration value back to configuration json file
def update_json_file(file_path, key, value):
    # Load the JSON configuration file
    with open(file_path, 'r') as file:
        config = json.load(file)

    # Update the value
    config[key] = value

    # Write the updated configuration back to the file
    with open(file_path, 'w') as file:
        json.dump(config, file, indent=4)
        print(f"{file_path} updated. {key}: {value}")

# %% [markdown]
# **Create a deployment for llama.cpp in SAP AI Core**
# - configuration_id
# - resource_group
# <br/><br/>
# The created deployment id will be written back to [env.json](env.json), which will be used in
# - [02-llama.cpp.ipynb](02-llama.cpp.ipynb)to test the inference of open-source llms with llama.cpp server in SAP AI Core
# - [04-cleanup.ipynb](04-cleanup.ipynb) to stop and delete the deployment and clean up the resource.

# %%
# Create a Deployment in SAP AI Core
print("Creating deployment.")
response = client.deployment.create(
    configuration_id=configuration_id,
    resource_group=resource_group
)

# last_check_time will be used to check the deployment status continuously afterwards
# set initial last_check_time right after creating deployment
last_check_time = get_current_time()
deployment_start_time = datetime.now()

deployment_id = response.id
status = response.status
update_json_file("env.json", "deployment_id", deployment_id)
print("Deployment Result:\n", response.__dict__)
# Out:
# Creating deployment.
# env.json updated. deployment_id: d2b3f7ffbde78b38
# Deployment Result:
#  {'id': 'd2b3f7ffbde78b38', 'message': 'Deployment scheduled.', 'deployment_url': '', 'status': <Status.UNKNOWN: 'UNKNOWN'>, 'ttl': None}

# %% [markdown]
# #### 5.Check the status and logs of the deployment

# %%
print("5.Checking deployment status.")
deployment_url = f"{base_url}/deployments/{deployment_id}"
deployment_log_url = f"{deployment_url}/logs?start="
interval_s = 20

while status != "RUNNING" and status != "DEAD":
    current_time = get_current_time()
    #check deployment status
    response = requests.get(url=deployment_url, headers=headers)
    resp = response.json()
    
    status = resp['status']
    print(f'...... Deployment Status at {current_time}......', flush=False)
    print(f"Deployment status: {status}")

    #retrieve deployment logs
    response_log = requests.get(url=f"{deployment_log_url}{last_check_time}", headers=headers)
    last_check_time = current_time
    print(f"Deployment logs: {response_log.text}")

    # Sleep for 60 secs to avoid overwhelming the API with requests
    time.sleep(interval_s)

deployment_end_time = datetime.now()
duration_in_min = (deployment_end_time - deployment_start_time) / 60

if status == "RUNNING":
    print("Deployment is up and running now!")
else:
    print(f"Deployment {deployment_id} failed!")   

print(f"Deployment duration: {duration_in_min} mins")
# Out:
# 5.Checking deployment status.
# ...... Deployment Status at 2024-03-27T09:39:40.825379Z......
# Deployment status: UNKNOWN
# Deployment logs: {
#   "error": {
#     "code": "05011000",
#     "message": "DeploymentNotFoundError: Deployment d2b3f7ffbde78b38 not found.",
#     "target": "/api/v4alpha/deployments/d2b3f7ffbde78b38/logs"
#   }
# }
#
# ...... Deployment Status at 2024-03-27T09:40:03.404014Z......
# Deployment status: UNKNOWN
# Deployment logs: {
#   "error": {
#     "code": "05011000",
#     "message": "DeploymentNotFoundError: Deployment d2b3f7ffbde78b38 not found.",
#     "target": "/api/v4alpha/deployments/d2b3f7ffbde78b38/logs"
#   }
# }
#
# ...... Deployment Status at 2024-03-27T09:40:25.986644Z......
# Deployment status: UNKNOWN
# Deployment logs: {
#   "data": {
#     "result": []
#   }
# }
#
# ...... Deployment Status at 2024-03-27T09:40:56.702019Z......
# Deployment status: PENDING
# Deployment logs: {
#   "data": {
#     "result": []
#   }
# }
#
# ...... Deployment Status at 2024-03-27T09:41:31.801897Z......
# Deployment status: PENDING
# Deployment logs: {
#   "data": {
#     "result": []
#   }
# }
#
# ...... Deployment Status at 2024-03-27T09:42:01.090056Z......
# Deployment status: PENDING
# Deployment logs: {
#   "data": {
#     "result": []
#   }
# }
#
# ...... Deployment Status at 2024-03-27T09:42:23.827964Z......
# Deployment status: PENDING
# Deployment logs: {
#   "data": {
#     "result": []
#   }
# }
#
# ...... Deployment Status at 2024-03-27T09:42:46.769803Z......
# Deployment status: PENDING
# Deployment logs: {
#   "data": {
#     "result": []
#   }
# }
#
# ...... Deployment Status at 2024-03-27T09:43:15.504305Z......
# Deployment status: PENDING
# Deployment logs: {
#   "data": {
#     "result": []
#   }
# }
#
# ...... Deployment Status at 2024-03-27T09:43:42.777841Z......
# Deployment status: PENDING
# Deployment logs: {
#   "data": {
#     "result": []
#   }
# }
#
# ...... Deployment Status at 2024-03-27T09:44:05.921006Z......
# Deployment status: PENDING
# Deployment logs: {
#   "data": {
#     "result": []
#   }
# }
#
# ...... Deployment Status at 2024-03-27T09:44:32.952502Z......
# Deployment status: PENDING
# Deployment logs: {
#   "data": {
#     "result": []
#   }
# }
#
# ...... Deployment Status at 2024-03-27T09:45:06.510881Z......
# Deployment status: PENDING
# Deployment logs: {
#   "data": {
#     "result": [
#       {
#         "container": "kserve-container",
#         "msg": "-------------Starting llama.cpp Server--------------",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.607617616+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "--2024-03-27 09:44:55--  https://huggingface.co/TheBloke/Mistral-7B-Instruct-v0.2-GGUF/resolve/main/mistral-7b-instruct-v0.2.Q5_K_M.gguf",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.610427618+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "Resolving huggingface.co (huggingface.co)... 3.160.150.50, 3.160.150.7, 3.160.150.119, ...",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.626494169+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "Connecting to huggingface.co (huggingface.co)|3.160.150.50|:443... connected.",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.628098726+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "HTTP request sent, awaiting response... 302 Found",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.737441778+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "Location: https://cdn-lfs-us-1.huggingface.co/repos/72/62/726219e98582d16c24a66629a4dec1b0761b91c918e15dea2625b4293c134a92/b85cdd596ddd76f3194047b9108a73c74d77ba04bef49255a50fc0cfbda83d32?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27mistral-7b-instruct-v0.2.Q5_K_M.gguf%3B+filename%3D%22mistral-7b-instruct-v0.2.Q5_K_M.gguf%22%3B&Expires=1711791895&Policy=&Signature=L0BxXmyUHKokdff4KVbi9WEJ1yyfYmN0GXmfk64MFADfjAkaqbJojLYfATQx7nhgp334FoVYlk8KtEeRsx60zc-vjn4p4DYjzVNGsqSj7%7ExD2yl%7EMZdOPOBy-Yd%7EN3RzuNfQ49g6nor3wYiJyYetqfBDa94uJuny%7EA6GAYBIcblIrtyF6Dbu4-RGqnrVV3oDDWLehK%7EP%7EsPq11nk8qvIYSQ57%7EKn9LH8cf69Fu4GxafXpRcQOrzM3uHQDSyUGR88w6cVe4hmRJx5wzTR6YmlWxoFTjZoHCHF7y9VJ%7Eus39p8JL3mXSe15ZHbhDSUqjBjFNhv4RrQt8dSK7cHdfzkjg__&Key-Pair-Id=KCD77M1F0VK2B [following]",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.737460613+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "--2024-03-27 09:44:55--  https://cdn-lfs-us-1.huggingface.co/repos/72/62/726219e98582d16c24a66629a4dec1b0761b91c918e15dea2625b4293c134a92/b85cdd596ddd76f3194047b9108a73c74d77ba04bef49255a50fc0cfbda83d32?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27mistral-7b-instruct-v0.2.Q5_K_M.gguf%3B+filename%3D%22mistral-7b-instruct-v0.2.Q5_K_M.gguf%22%3B&Expires=1711791895&Policy=&Signature=L0BxXmyUHKokdff4KVbi9WEJ1yyfYmN0GXmfk64MFADfjAkaqbJojLYfATQx7nhgp334FoVYlk8KtEeRsx60zc-vjn4p4DYjzVNGsqSj7%7ExD2yl%7EMZdOPOBy-Yd%7EN3RzuNfQ49g6nor3wYiJyYetqfBDa94uJuny%7EA6GAYBIcblIrtyF6Dbu4-RGqnrVV3oDDWLehK%7EP%7EsPq11nk8qvIYSQ57%7EKn9LH8cf69Fu4GxafXpRcQOrzM3uHQDSyUGR88w6cVe4hmRJx5wzTR6YmlWxoFTjZoHCHF7y9VJ%7Eus39p8JL3mXSe15ZHbhDSUqjBjFNhv4RrQt8dSK7cHdfzkjg__&Key-Pair-Id=KCD77M1F0VK2B",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.737483024+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "Resolving cdn-lfs-us-1.huggingface.co (cdn-lfs-us-1.huggingface.co)... 13.32.121.50, 13.32.121.62, 13.32.121.59, ...",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.749615907+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "Connecting to cdn-lfs-us-1.huggingface.co (cdn-lfs-us-1.huggingface.co)|13.32.121.50|:443... connected.",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.752532243+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "HTTP request sent, awaiting response... 200 OK",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.907545566+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "Length: 5131409696 (4.8G) [binary/octet-stream]",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.907733201+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "Saving to: \u2018/models/mistral-7b-instruct-v0.2.Q5_K_M.gguf\u2019",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.907933473+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.908024072+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "     0K .......... .......... .......... .......... ..........  0% 42.5M 1m55s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.909132242+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "    50K .......... .......... .......... .......... ..........  0%  101M 82s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.909599542+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "   100K .......... .......... .......... .......... ..........  0% 58.9M 82s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.910440921+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "   150K .......... .......... .......... .......... ..........  0%  152M 70s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.910780191+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "   200K .......... .......... .......... .......... ..........  0% 91.5M 66s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.911297082+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "   250K .......... .......... .......... .......... ..........  0% 35.3M 79s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.912688732+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "   300K .......... .......... .......... .......... ..........  0%  106M 74s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.913120031+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "   350K .......... .......... .......... .......... ..........  0%  155M 69s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.913439989+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "   400K .......... .......... .......... .......... ..........  0%  151M 65s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.913760185+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "   450K .......... .......... .......... .......... ..........  0%  188M 61s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.914029598+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "   500K .......... .......... .......... .......... ..........  0%  201M 57s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.914277315+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "   550K .......... .......... .......... .......... ..........  0%  186M 55s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.914533853+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "   600K .......... .......... .......... .......... ..........  0%  127M 54s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.914978742+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "   650K .......... .......... .......... .......... ..........  0%  138M 52s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.915254592+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "   700K .......... .......... .......... .......... ..........  0%  168M 51s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.915549993+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "   750K .......... .......... .......... .......... ..........  0%  124M 50s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.915956497+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "   800K .......... .......... .......... .......... ..........  0%  143M 49s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.916385412+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "   850K .......... .......... .......... .......... ..........  0% 91.1M 49s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.916865587+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "   900K .......... .......... .......... .......... ..........  0%  166M 48s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.917134523+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "   950K .......... .......... .......... .......... ..........  0%  190M 47s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.917589187+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  1000K .......... .......... .......... .......... ..........  0% 58.2M 49s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.918225765+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  1050K .......... .......... .......... .......... ..........  0%  164M 48s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.918550968+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  1100K .......... .......... .......... .......... ..........  0%  156M 47s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.918927907+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  1150K .......... .......... .......... .......... ..........  0% 36.1M 51s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.920307159+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  1200K .......... .......... .......... .......... ..........  0%  117M 51s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.920619726+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  1250K .......... .......... .......... .......... ..........  0%  145M 50s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.920973539+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  1300K .......... .......... .......... .......... ..........  0%  152M 49s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.921303510+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  1350K .......... .......... .......... .......... ..........  0%  161M 49s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.921601057+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  1400K .......... .......... .......... .......... ..........  0%  195M 48s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.921841382+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  1450K .......... .......... .......... .......... ..........  0%  101M 48s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.922280073+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  1500K .......... .......... .......... .......... ..........  0%  188M 47s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.922556877+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  1550K .......... .......... .......... .......... ..........  0%  148M 47s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.922869920+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  1600K .......... .......... .......... .......... ..........  0%  222M 46s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.923106193+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  1650K .......... .......... .......... .......... ..........  0%  142M 46s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.923453807+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  1700K .......... .......... .......... .......... ..........  0%  169M 45s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.923738956+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  1750K .......... .......... .......... .......... ..........  0%  187M 45s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.924039363+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  1800K .......... .......... .......... .......... ..........  0%  211M 44s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.924259662+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  1850K .......... .......... .......... .......... ..........  0%  158M 44s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.924562454+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  1900K .......... .......... .......... .......... ..........  0%  154M 43s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.924864292+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  1950K .......... .......... .......... .......... ..........  0%  187M 43s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.925168514+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  2000K .......... .......... .......... .......... ..........  0%  141M 43s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.925486326+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  2050K .......... .......... .......... .......... ..........  0%  169M 42s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.925752639+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  2100K .......... .......... .......... .......... ..........  0%  180M 42s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.926059007+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  2150K .......... .......... .......... .......... ..........  0%  116M 42s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.926449537+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  2200K .......... .......... .......... .......... ..........  0%  182M 42s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.926773309+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  2250K .......... .......... .......... .......... ..........  0%  142M 42s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.927055597+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  2300K .......... .......... .......... .......... ..........  0%  182M 41s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.927316665+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  2350K .......... .......... .......... .......... ..........  0%  179M 41s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.927593469+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  2400K .......... .......... .......... .......... ..........  0%  178M 41s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.927879095+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  2450K .......... .......... .......... .......... ..........  0%  167M 40s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.928172588+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  2500K .......... .......... .......... .......... ..........  0%  181M 40s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.928475379+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  2550K .......... .......... .......... .......... ..........  0%  156M 40s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.928770542+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  2600K .......... .......... .......... .......... ..........  0%  173M 40s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.929076671+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  2650K .......... .......... .......... .......... ..........  0%  158M 40s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.929342985+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  2700K .......... .......... .......... .......... ..........  0%  171M 39s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.929631948+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  2750K .......... .......... .......... .......... ..........  0%  158M 39s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.929939031+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  2800K .......... .......... .......... .......... ..........  0%  143M 39s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.930284976+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  2850K .......... .......... .......... .......... ..........  0%  166M 39s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.930577516+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  2900K .......... .......... .......... .......... ..........  0%  157M 39s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.930877685+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  2950K .......... .......... .......... .......... ..........  0%  175M 39s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.931192636+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  3000K .......... .......... .......... .......... ..........  0%  172M 39s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.931484699+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  3050K .......... .......... .......... .......... ..........  0%  177M 38s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.931714773+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  3100K .......... .......... .......... .......... ..........  0%  190M 38s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.931976556+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  3150K .......... .......... .......... .......... ..........  0%  162M 38s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.932265758+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  3200K .......... .......... .......... .......... ..........  0%  177M 38s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.932548522+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  3250K .......... .......... .......... .......... ..........  0%  156M 38s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.932859659+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  3300K .......... .......... .......... .......... ..........  0%  221M 38s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.933088064+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  3350K .......... .......... .......... .......... ..........  0%  196M 37s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.933337211+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  3400K .......... .......... .......... .......... ..........  0%  189M 37s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.933598756+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  3450K .......... .......... .......... .......... ..........  0%  184M 37s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.933851480+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  3500K .......... .......... .......... .......... ..........  0%  209M 37s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.934089899+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  3550K .......... .......... .......... .......... ..........  0%  198M 37s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.934347152+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  3600K .......... .......... .......... .......... ..........  0%  192M 37s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.934604883+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  3650K .......... .......... .......... .......... ..........  0%  185M 36s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.934850692+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  3700K .......... .......... .......... .......... ..........  0%  227M 36s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.935065746+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  3750K .......... .......... .......... .......... ..........  0%  230M 36s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.935295104+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  3800K .......... .......... .......... .......... ..........  0%  163M 36s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.935578107+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  3850K .......... .......... .......... .......... ..........  0%  169M 36s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.935871601+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  3900K .......... .......... .......... .......... ..........  0%  168M 36s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.936180353+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  3950K .......... .......... .......... .......... ..........  0%  200M 36s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.936505794+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  4000K .......... .......... .......... .......... ..........  0%  142M 36s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.936765909+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  4050K .......... .......... .......... .......... ..........  0%  166M 36s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.937053442+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  4100K .......... .......... .......... .......... ..........  0%  185M 35s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.937318801+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  4150K .......... .......... .......... .......... ..........  0%  187M 35s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.937600851+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  4200K .......... .......... .......... .......... ..........  0%  131M 35s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.937951564+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  4250K .......... .......... .......... .......... ..........  0%  183M 35s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.938226699+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  4300K .......... .......... .......... .......... ..........  0%  199M 35s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.938474416+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  4350K .......... .......... .......... .......... ..........  0%  210M 35s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.938728570+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  4400K .......... .......... .......... .......... ..........  0%  144M 35s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.939027070+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  4450K .......... .......... .......... .......... ..........  0%  195M 35s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.939303874+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  4500K .......... .......... .......... .......... ..........  0%  241M 35s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.939500331+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  4550K .......... .......... .......... .......... ..........  0%  206M 35s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.939705848+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  4600K .......... .......... .......... .......... ..........  0%  207M 34s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.939960956+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  4650K .......... .......... .......... .......... ..........  0%  201M 34s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.940194845+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  4700K .......... .......... .......... .......... ..........  0%  189M 34s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.940468311+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  4750K .......... .......... .......... .......... ..........  0%  162M 34s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.940762042+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  4800K .......... .......... .......... .......... ..........  0%  161M 34s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.941098213+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  4850K .......... .......... .......... .......... ..........  0%  228M 34s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.941324472+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  4900K .......... .......... .......... .......... ..........  0%  187M 34s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.941532135+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  4950K .......... .......... .......... .......... ..........  0%  178M 34s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.941803455+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  5000K .......... .......... .......... .......... ..........  0%  181M 34s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.942077636+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  5050K .......... .......... .......... .......... ..........  0%  165M 34s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.942379474+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  5100K .......... .......... .......... .......... ..........  0%  177M 34s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.942642450+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  5150K .......... .......... .......... .......... ..........  0%  156M 34s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.942947149+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  5200K .......... .......... .......... .......... ..........  0%  217M 34s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.943196296+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  5250K .......... .......... .......... .......... ..........  0%  183M 34s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.943494081+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  5300K .......... .......... .......... .......... ..........  0%  210M 33s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.943679094+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  5350K .......... .......... .......... .......... ..........  0%  168M 33s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.944003582+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  5400K .......... .......... .......... .......... ..........  0%  205M 33s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.944231510+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  5450K .......... .......... .......... .......... ..........  0%  202M 33s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.944492340+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  5500K .......... .......... .......... .......... ..........  0%  241M 33s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.944643974+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  5550K .......... .......... .......... .......... ..........  0%  202M 33s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.944894313+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  5600K .......... .......... .......... .......... ..........  0%  167M 33s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.945178270+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  5650K .......... .......... .......... .......... ..........  0%  130M 33s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.945583581+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  5700K .......... .......... .......... .......... ..........  0%  181M 33s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.945820808+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  5750K .......... .......... .......... .......... ..........  0%  213M 33s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.946068763+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  5800K .......... .......... .......... .......... ..........  0%  148M 33s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.946384906+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  5850K .......... .......... .......... .......... ..........  0%  182M 33s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.946653366+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  5900K .......... .......... .......... .......... ..........  0%  153M 33s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.946974277+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  5950K .......... .......... .......... .......... ..........  0%  195M 33s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.947245597+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  6000K .......... .......... .......... .......... ..........  0%  162M 33s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.947556018+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  6050K .......... .......... .......... .......... ..........  0%  156M 33s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.947870016+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  6100K .......... .......... .......... .......... ..........  0%  202M 33s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.948106288+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  6150K .......... .......... .......... .......... ..........  0%  219M 33s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.948315143+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  6200K .......... .......... .......... .......... ..........  0%  172M 33s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.948585987+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  6250K .......... .......... .......... .......... ..........  0%  135M 33s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.948954343+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  6300K .......... .......... .......... .......... ..........  0%  208M 32s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.949187278+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  6350K .......... .......... .......... .......... ..........  0%  221M 32s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.949390649+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  6400K .......... .......... .......... .......... ..........  0%  212M 32s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.949644327+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  6450K .......... .......... .......... .......... ..........  0%  142M 32s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.949975490+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  6500K .......... .......... .......... .......... ..........  0%  179M 32s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.950265645+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  6550K .......... .......... .......... .......... ..........  0%  170M 32s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.950560569+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  6600K .......... .......... .......... .......... ..........  0%  133M 32s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.950921535+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  6650K .......... .......... .......... .......... ..........  0%  152M 32s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.951230764+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": "  6700K .......... .......... .......... .......... ..........  0%  197M 32s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:55.951475620+00:00"
#       },
#       {
#         "container": "kserve-container",
# ...
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.175952434+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": " 46950K .......... .......... .......... .......... ..........  0%  209M 28s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.176216125+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": " 47000K .......... .......... .......... .......... ..........  0%  190M 28s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.176454544+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": " 47050K .......... .......... .......... .......... ..........  0%  187M 28s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.176683902+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": " 47100K .......... .......... .......... .......... ..........  0%  221M 28s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.176915407+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": " 47150K .......... .......... .......... .......... ..........  0%  170M 28s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.177223205+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": " 47200K .......... .......... .......... .......... ..........  0%  135M 28s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.177567481+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": " 47250K .......... .......... .......... .......... ..........  0%  135M 28s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.177929401+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": " 47300K .......... .......... .......... .......... ..........  0%  168M 28s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.178244113+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": " 47350K .......... .......... .......... .......... ..........  0%  176M 28s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.178529500+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": " 47400K .......... .......... .......... .......... ..........  0%  174M 28s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.178802251+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": " 47450K .......... .......... .......... .......... ..........  0%  158M 28s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.179102897+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": " 47500K .......... .......... .......... .......... ..........  0%  231M 28s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.179308414+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": " 47550K .......... .......... .......... .......... ..........  0%  184M 28s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.179581165+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": " 47600K .......... .......... .......... .......... ..........  0%  200M 28s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.179781675+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": " 47650K .......... .......... .......... .......... ..........  0%  181M 28s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.180068254+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": " 47700K .......... .......... .......... .......... ..........  0%  164M 28s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.180379629+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": " 47750K .......... .......... .......... .......... ..........  0%  231M 28s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.180592536+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": " 47800K .......... .......... .......... .......... ..........  0%  202M 28s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.180815458+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": " 47850K .......... .......... .......... .......... ..........  0%  245M 28s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.181011199+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": " 47900K .......... .......... .......... .......... ..........  0%  220M 28s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.181266307+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": " 47950K .......... .......... .......... .......... ..........  0%  207M 28s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.181485414+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": " 48000K .......... .......... .......... .......... ..........  0%  198M 28s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.181737899+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": " 48050K .......... .......... .......... .......... ..........  0%  136M 28s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.182116746+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": " 48100K .......... .......... .......... .......... ..........  0%  176M 28s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.182397842+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": " 48150K .......... .......... .......... .......... ..........  0%  182M 28s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.182649612+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": " 48200K .......... .......... .......... .......... ..........  0%  173M 28s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.182937860+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": " 48250K .......... .......... .......... .......... ..........  0%  129M 28s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.183321237+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": " 48300K .......... .......... .......... .......... ..........  0%  166M 28s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.183608055+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": " 48350K .......... .......... .......... .......... ..........  0%  175M 28s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.183882236+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": " 48400K .......... .......... .......... .......... ..........  0%  177M 28s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.184151411+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": " 48450K .......... .......... .......... .......... ..........  0%  160M 28s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.184458494+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": " 48500K .......... .......... .......... .......... ..........  0%  209M 28s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.184699773+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": " 48550K .......... .......... .......... .......... ..........  0%  187M 28s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.184983491+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": " 48600K .......... .......... .......... .......... ..........  0%  190M 28s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.185222864+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": " 48650K .......... .......... .......... .......... ..........  0%  186M 28s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.185471534+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": " 48700K .......... .......... .......... .......... ..........  0%  223M 28s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.185747861+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": " 48750K .......... .......... .......... .......... ..........  0%  170M 28s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.186014652+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": " 48800K .......... .......... .......... .......... ..........  0%  211M 28s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.186215877+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": " 48850K .......... .......... .......... .......... ..........  0%  190M 28s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.186461448+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": " 48900K .......... .......... .......... .......... ..........  0%  151M 28s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.186771392+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": " 48950K .......... .......... .......... .......... ..........  0%  173M 28s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.187065601+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": " 49000K .......... .......... .......... .......... ..........  0%  136M 28s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.187438726+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": " 49050K .......... .......... .......... .......... ..........  0%  198M 28s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.187692880+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": " 49100K .......... .......... .......... .......... ..........  0%  196M 28s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.187918663+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": " 49150K .......... .......... .......... .......... ..........  0%  179M 28s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.188766241+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": " 49200K .......... .......... .......... .......... ..........  0%  170M 28s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.188776969+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": " 49250K .......... .......... .......... .......... ..........  0%  197M 28s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.188788175+00:00"
#       },
#       {
#         "container": "kserve-container",
#         "msg": " 49300K .......... .......... .......... .......... ..........  0%  181M 28s",
#         "pod": "d2b3f7ffbde78b38-predictor-default-00001-deployment-558d85qbhjx",
#         "timestamp": "2024-03-27T09:44:56.189021348+00:00"
#       }
#     ]
#   }
# }
#
# ...... Deployment Status at 2024-03-27T09:45:31.283599Z......
# Deployment status: PENDING
# Deployment logs: {
#   "data": {
#     "result": []
#   }
# }
#
# ...... Deployment Status at 2024-03-27T09:45:54.472178Z......
# Deployment status: PENDING
# Deployment logs: {
#   "data": {
#     "result": []
#   }
# }
#
# ...... Deployment Status at 2024-03-27T09:46:22.246053Z......
# Deployment status: PENDING
# Deployment logs: {
#   "data": {
#     "result": []
#   }
# }
#
# ...... Deployment Status at 2024-03-27T09:46:52.247001Z......
# Deployment status: PENDING
# Deployment logs: {
#   "data": {
#     "result": []
#   }
# }
#
# ...... Deployment Status at 2024-03-27T09:47:21.967588Z......
# Deployment status: PENDING
# Deployment logs: {
#   "data": {
#     "result": []
#   }
# }
#
# ...... Deployment Status at 2024-03-27T09:47:44.723406Z......
# Deployment status: PENDING
# Deployment logs: {
#   "data": {
#     "result": []
#   }
# }
#
# ...... Deployment Status at 2024-03-27T09:48:07.719270Z......
# Deployment status: PENDING
# Deployment logs: {
#   "data": {
#     "result": []
#   }
# }
#
# ...... Deployment Status at 2024-03-27T09:48:37.517065Z......
# Deployment status: PENDING
# Deployment logs: {
#   "data": {
#     "result": []
#   }
# }
#
# ...... Deployment Status at 2024-03-27T09:49:08.428292Z......
# Deployment status: PENDING
# Deployment logs: {
#   "data": {
#     "result": []
#   }
# }
#
# ...... Deployment Status at 2024-03-27T09:49:30.909552Z......
# Deployment status: PENDING
# Deployment logs: {
#   "data": {
#     "result": []
#   }
# }
#
# ...... Deployment Status at 2024-03-27T09:49:59.443196Z......
# Deployment status: RUNNING
# Deployment logs: {
#   "data": {
#     "result": []
#   }
# }
#
# Deployment is up and running now!
# Deployment duration: 0:00:11.024313 mins
